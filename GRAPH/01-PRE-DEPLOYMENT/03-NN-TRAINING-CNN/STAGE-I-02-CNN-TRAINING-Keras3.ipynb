# %% [markdown]
# # CNN FOR EVENT CLASSIFICATION

# %% [markdown]
# ## DATA GENERATION

# %%
# DEPENDENCIES

import numpy as np
import sys
import os
import matplotlib.pyplot as plt
import random
import time
import datetime
import pandas as pd

import prenn # for deep learning

# %%
# RAW DATA
AVPath = '../DATA/SYN_RES/RESPONSE_AV.npy'
EQPath = '../DATA/SYN_RES/RESPONSE_EQ.npy'
IPPath = '../DATA/SYN_RES/RESPONSE_IP.npy'
SWPath = '../DATA/SYN_RES/RESPONSE_SW.npy'

# Load Data + add noise to the data
RESPONSE_AV = np.load(AVPath)
RESPONSE_EQ = np.load(EQPath)
RESPONSE_IP = np.load(IPPath)
RESPONSE_SW = np.load(SWPath)

## only use part of the data
raw_len = RESPONSE_AV.shape[0]
ratio = 1.0 # ALL DATA USED FOR TRAINING
use_len = int(raw_len * ratio)

RESPONSE_AV = RESPONSE_AV[:use_len]
RESPONSE_EQ = RESPONSE_EQ[:use_len]
RESPONSE_IP = RESPONSE_IP[:use_len]
RESPONSE_SW = RESPONSE_SW[:use_len]

## Check Data Info
print(type(RESPONSE_AV))
print('RESPONSE_AV Shape:', RESPONSE_AV.shape)
print(type(RESPONSE_EQ))
print('RESPONSE_EQ Shape:', RESPONSE_EQ.shape)
print(type(RESPONSE_IP))
print('RESPONSE_IP Shape:', RESPONSE_IP.shape)
print(type(RESPONSE_SW))
print('RESPONSE_SW Shape:', RESPONSE_SW.shape)
# Out:
# <class 'numpy.ndarray'>
# RESPONSE_AV Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_EQ Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_IP Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_SW Shape: (1000, 6000)

# %%
## Check Random Data
selected_idx = np.random.randint(RESPONSE_AV.shape[0])

## Plot Random Data - use subplot
plt.figure(figsize=(30, 10))
plt.subplot(2, 2, 1)
plt.plot(RESPONSE_AV[selected_idx, :])
plt.title('AV')
plt.subplot(2, 2, 2)
plt.plot(RESPONSE_EQ[selected_idx, :])
plt.title('EQ')
plt.subplot(2, 2, 3)
plt.plot(RESPONSE_IP[selected_idx, :])
plt.title('IP')
plt.subplot(2, 2, 4)
plt.plot(RESPONSE_SW[selected_idx, :])
plt.title('SW')
plt.show()

# %%
num_type = 4

reshape_shape_0 = RESPONSE_AV.shape[0]
reshape_shape_1 = RESPONSE_AV.shape[1]

LenTS = reshape_shape_1

# %%
# Integrate All Data into a 2D Array

## Reshape Data
RESPONSE_AV_RESHAPED = RESPONSE_AV.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_EQ_RESHAPED = RESPONSE_EQ.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_IP_RESHAPED = RESPONSE_IP.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_SW_RESHAPED = RESPONSE_SW.reshape(reshape_shape_0, reshape_shape_1)

## Stack Data
RESPONSE = np.vstack((RESPONSE_AV_RESHAPED, RESPONSE_EQ_RESHAPED, RESPONSE_IP_RESHAPED, RESPONSE_SW_RESHAPED))

## Total Number of Samples
NumSample = RESPONSE.shape[0]
print('Total Number of Samples:', NumSample)
# Out:
# Total Number of Samples: 4000

# %%
# Real Ground Truth

## Binary Form, Interest or Not
Real_GT_B = np.zeros((RESPONSE.shape[0], 1))

## Real_GT_B, only the first quarter of the data is considered as not interesting
for i in range(RESPONSE_AV.shape[0], RESPONSE.shape[0]):
    Real_GT_B[i] = 1

## plot the binary form
plt.figure()
plt.plot(Real_GT_B)
plt.show()

## Multi-Class Form, Event Type
Real_GT_M = np.zeros((RESPONSE.shape[0], 4))

## Real_GT_M, 4 types of events
for i in range(num_type):
    Real_GT_M[i*reshape_shape_0:(i+1)*reshape_shape_0, i] = 1

## plot the multi-class form, 4 subplots, each subplot for one type of event
plt.figure(figsize=(30, 10))
plt.subplot(4, 1, 1)
plt.plot(Real_GT_M[:, 0])
plt.title('AV')
plt.subplot(4, 1, 2)
plt.plot(Real_GT_M[:, 1])
plt.title('EQ')
plt.subplot(4, 1, 3)
plt.plot(Real_GT_M[:, 2])
plt.title('IP')
plt.subplot(4, 1, 4)
plt.plot(Real_GT_M[:, 3])
plt.title('SW')
plt.show()

# %%
# process parameters

# nn input length
nn_in_len = 128

# time step
dt = 0.01

# nperseg
nperseg = 128

# output length

# %%
NN_IN_DATA = np.zeros((NumSample, nn_in_len))

for i in range(NumSample):
    NN_IN_DATA[i, :] = prenn.prenn(RESPONSE[i, :].reshape(1, -1), dt, nperseg, nn_in_len)

# %%
# check whether nan exists
nan_idx = np.argwhere(np.isnan(NN_IN_DATA))
print(nan_idx)
# Out:
# []

# %%
# plot to check
# selected_idx = np.random.randint(NumSample)
selected_idx = 599
plt.figure()
plt.plot(NN_IN_DATA[selected_idx, :])
plt.show()

# %%
# save data as npy file
np.save('NN_IN_DATA.npy', NN_IN_DATA)

# %%
# LABELS
NN_IN_LABEL = np.zeros((NumSample, 1))
NN_IN_LABEL_1HOT = np.zeros((NumSample, 4))

# %%
# NN_IN_LABEL & NN_IN_LABEL_1HOT
for i in range(NumSample):
    if i < reshape_shape_0:
        NN_IN_LABEL[i] = 0
        NN_IN_LABEL_1HOT[i, 0] = 1
    elif i < reshape_shape_0 * 2:
        NN_IN_LABEL[i] = 1
        NN_IN_LABEL_1HOT[i, 1] = 1
    elif i < reshape_shape_0 * 3:
        NN_IN_LABEL[i] = 2
        NN_IN_LABEL_1HOT[i, 2] = 1
    else:
        NN_IN_LABEL[i] = 3
        NN_IN_LABEL_1HOT[i, 3] = 1

# %%
## plot NN_IN_LABEL
plt.figure()
plt.plot(NN_IN_LABEL)
plt.show()

# %%
## plot NN_IN_LABEL_1HOT
plt.figure(figsize=(30, 10))
plt.subplot(4, 1, 1)
plt.plot(NN_IN_LABEL_1HOT[:, 0])
plt.title('AV')
plt.subplot(4, 1, 2)
plt.plot(NN_IN_LABEL_1HOT[:, 1])
plt.title('EQ')
plt.subplot(4, 1, 3)
plt.plot(NN_IN_LABEL_1HOT[:, 2])
plt.title('IP')
plt.subplot(4, 1, 4)
plt.plot(NN_IN_LABEL_1HOT[:, 3])
plt.title('SW')
plt.show()

# %%
# save data as npy file
np.save('NN_IN_LABEL.npy', NN_IN_LABEL)
np.save('NN_IN_LABEL_1HOT.npy', NN_IN_LABEL_1HOT)

# %% [markdown]
# ## CNN MODEL FOR CLASSIFICATION

# %%
# dependencies
import numpy as np
import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
import tf2onnx
import onnx
# Out:
# WARNING:tensorflow:From C:\Users\cswof\AppData\Roaming\Python\Python312\site-packages\tf2onnx\tf_loader.py:68: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\cswof\AppData\Roaming\Python\Python312\site-packages\tf2onnx\tf_loader.py:72: The name tf.train.import_meta_graph is deprecated. Please use tf.compat.v1.train.import_meta_graph instead.

# %%
# data preparation

data = np.load('NN_IN_DATA.npy')
# expand dimensions to 3D
data = np.expand_dims(data, axis=2)

print(data.shape)

label_1h = np.load('NN_IN_LABEL_1HOT.npy').astype(int)
print(label_1h.shape)

label = np.argmax(label_1h, axis=1).astype(int)
label = label.reshape((-1,1))

print(label.shape)
# Out:
# (4000, 128, 1)
# (4000, 4)
# (4000, 1)

# %%
# split data as x_train, x_test, y_train, y_test
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=42)

# check info
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3200, 128, 1)
# (800, 128, 1)
# (3200, 1)
# (800, 1)

# %%
num_classes = np.unique(label).shape[0]
print(num_classes)
# Out:
# 4

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=4, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    # conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    # conv2 = keras.layers.BatchNormalization()(conv2)
    # conv2 = keras.layers.ReLU()(conv2)

    # conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    # conv3 = keras.layers.BatchNormalization()(conv3)
    # conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv1)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
# keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 150
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 1.3788 - sparse_categorical_accuracy: 0.4970 - val_loss: 1.3770 - val_sparse_categorical_accuracy: 0.3578 - learning_rate: 0.0010
# Epoch 2/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3474 - sparse_categorical_accuracy: 0.4884 - val_loss: 1.3503 - val_sparse_categorical_accuracy: 0.3359 - learning_rate: 0.0010
# Epoch 3/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2945 - sparse_categorical_accuracy: 0.5282 - val_loss: 1.3180 - val_sparse_categorical_accuracy: 0.4859 - learning_rate: 0.0010
# Epoch 4/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2740 - sparse_categorical_accuracy: 0.5225 - val_loss: 1.2843 - val_sparse_categorical_accuracy: 0.4844 - learning_rate: 0.0010
# Epoch 5/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2543 - sparse_categorical_accuracy: 0.5195 - val_loss: 1.2524 - val_sparse_categorical_accuracy: 0.5016 - learning_rate: 0.0010
# Epoch 6/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2241 - sparse_categorical_accuracy: 0.5219 - val_loss: 1.2225 - val_sparse_categorical_accuracy: 0.7172 - learning_rate: 0.0010
# Epoch 7/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2007 - sparse_categorical_accuracy: 0.5593 - val_loss: 1.1956 - val_sparse_categorical_accuracy: 0.6234 - learning_rate: 0.0010
# Epoch 8/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1741 - sparse_categorical_accuracy: 0.5413 - val_loss: 1.1745 - val_sparse_categorical_accuracy: 0.7063 - learning_rate: 0.0010
# Epoch 9/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1544 - sparse_categorical_accuracy: 0.5570 - val_loss: 1.1477 - val_sparse_categorical_accuracy: 0.7391 - learning_rate: 0.0010
# Epoch 10/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1302 - sparse_categorical_accuracy: 0.5793 - val_loss: 1.1191 - val_sparse_categorical_accuracy: 0.5500 - learning_rate: 0.0010
# Epoch 11/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1031 - sparse_categorical_accuracy: 0.5960 - val_loss: 1.0943 - val_sparse_categorical_accuracy: 0.6109 - learning_rate: 0.0010
# Epoch 12/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0858 - sparse_categorical_accuracy: 0.5990 - val_loss: 1.0719 - val_sparse_categorical_accuracy: 0.8391 - learning_rate: 0.0010
# Epoch 13/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0524 - sparse_categorical_accuracy: 0.6593 - val_loss: 1.0451 - val_sparse_categorical_accuracy: 0.6625 - learning_rate: 0.0010
# Epoch 14/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0233 - sparse_categorical_accuracy: 0.6499 - val_loss: 1.0245 - val_sparse_categorical_accuracy: 0.6375 - learning_rate: 0.0010
# Epoch 15/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0044 - sparse_categorical_accuracy: 0.6963 - val_loss: 1.0005 - val_sparse_categorical_accuracy: 0.8797 - learning_rate: 0.0010
# Epoch 16/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9779 - sparse_categorical_accuracy: 0.7309 - val_loss: 0.9751 - val_sparse_categorical_accuracy: 0.7078 - learning_rate: 0.0010
# Epoch 17/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9521 - sparse_categorical_accuracy: 0.7424 - val_loss: 0.9490 - val_sparse_categorical_accuracy: 0.9141 - learning_rate: 0.0010
# Epoch 18/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9227 - sparse_categorical_accuracy: 0.7784 - val_loss: 0.9239 - val_sparse_categorical_accuracy: 0.8484 - learning_rate: 0.0010
# Epoch 19/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9037 - sparse_categorical_accuracy: 0.8032 - val_loss: 0.9026 - val_sparse_categorical_accuracy: 0.9500 - learning_rate: 0.0010
# Epoch 20/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8870 - sparse_categorical_accuracy: 0.8427 - val_loss: 0.8829 - val_sparse_categorical_accuracy: 0.9375 - learning_rate: 0.0010
# Epoch 21/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8666 - sparse_categorical_accuracy: 0.8277 - val_loss: 0.8644 - val_sparse_categorical_accuracy: 0.9328 - learning_rate: 0.0010
# Epoch 22/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8455 - sparse_categorical_accuracy: 0.8579 - val_loss: 0.8469 - val_sparse_categorical_accuracy: 0.9312 - learning_rate: 0.0010
# Epoch 23/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8243 - sparse_categorical_accuracy: 0.8740 - val_loss: 0.8207 - val_sparse_categorical_accuracy: 0.7406 - learning_rate: 0.0010
# Epoch 24/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8154 - sparse_categorical_accuracy: 0.8651 - val_loss: 0.8041 - val_sparse_categorical_accuracy: 0.9656 - learning_rate: 0.0010
# Epoch 25/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7975 - sparse_categorical_accuracy: 0.8943 - val_loss: 0.7860 - val_sparse_categorical_accuracy: 0.9453 - learning_rate: 0.0010
# Epoch 26/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7745 - sparse_categorical_accuracy: 0.8794 - val_loss: 0.7724 - val_sparse_categorical_accuracy: 0.9641 - learning_rate: 0.0010
# Epoch 27/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7745 - sparse_categorical_accuracy: 0.9099 - val_loss: 0.7608 - val_sparse_categorical_accuracy: 0.9469 - learning_rate: 0.0010
# Epoch 28/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7577 - sparse_categorical_accuracy: 0.9020 - val_loss: 0.7517 - val_sparse_categorical_accuracy: 0.9422 - learning_rate: 0.0010
# Epoch 29/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7506 - sparse_categorical_accuracy: 0.8995 - val_loss: 0.7324 - val_sparse_categorical_accuracy: 0.9563 - learning_rate: 0.0010
# Epoch 30/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7280 - sparse_categorical_accuracy: 0.9118 - val_loss: 0.7203 - val_sparse_categorical_accuracy: 0.9516 - learning_rate: 0.0010
# Epoch 31/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7235 - sparse_categorical_accuracy: 0.8968 - val_loss: 0.7023 - val_sparse_categorical_accuracy: 0.9688 - learning_rate: 0.0010
# Epoch 32/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7097 - sparse_categorical_accuracy: 0.9185 - val_loss: 0.7020 - val_sparse_categorical_accuracy: 0.9516 - learning_rate: 0.0010
# Epoch 33/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7015 - sparse_categorical_accuracy: 0.9288 - val_loss: 0.6868 - val_sparse_categorical_accuracy: 0.9625 - learning_rate: 0.0010
# Epoch 34/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6889 - sparse_categorical_accuracy: 0.9040 - val_loss: 0.6735 - val_sparse_categorical_accuracy: 0.9000 - learning_rate: 0.0010
# Epoch 35/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6871 - sparse_categorical_accuracy: 0.9125 - val_loss: 0.6709 - val_sparse_categorical_accuracy: 0.9469 - learning_rate: 0.0010
# Epoch 36/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6796 - sparse_categorical_accuracy: 0.9191 - val_loss: 0.6539 - val_sparse_categorical_accuracy: 0.9578 - learning_rate: 0.0010
# Epoch 37/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6686 - sparse_categorical_accuracy: 0.9055 - val_loss: 0.6516 - val_sparse_categorical_accuracy: 0.9531 - learning_rate: 0.0010
# Epoch 38/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6598 - sparse_categorical_accuracy: 0.9155 - val_loss: 0.6426 - val_sparse_categorical_accuracy: 0.9375 - learning_rate: 0.0010
# Epoch 39/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6479 - sparse_categorical_accuracy: 0.9357 - val_loss: 0.6308 - val_sparse_categorical_accuracy: 0.9703 - learning_rate: 0.0010
# Epoch 40/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6325 - sparse_categorical_accuracy: 0.9390 - val_loss: 0.6455 - val_sparse_categorical_accuracy: 0.9312 - learning_rate: 0.0010
# Epoch 41/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6260 - sparse_categorical_accuracy: 0.9466 - val_loss: 0.6116 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 42/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6134 - sparse_categorical_accuracy: 0.9244 - val_loss: 0.5978 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 43/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6075 - sparse_categorical_accuracy: 0.9369 - val_loss: 0.5866 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 44/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6083 - sparse_categorical_accuracy: 0.9486 - val_loss: 0.5830 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 45/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6053 - sparse_categorical_accuracy: 0.9487 - val_loss: 0.5845 - val_sparse_categorical_accuracy: 0.9234 - learning_rate: 0.0010
# Epoch 46/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5969 - sparse_categorical_accuracy: 0.9299 - val_loss: 0.5694 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 47/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5775 - sparse_categorical_accuracy: 0.9437 - val_loss: 0.5625 - val_sparse_categorical_accuracy: 0.9688 - learning_rate: 0.0010
# Epoch 48/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5753 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.5561 - val_sparse_categorical_accuracy: 0.9656 - learning_rate: 0.0010
# Epoch 49/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5716 - sparse_categorical_accuracy: 0.9416 - val_loss: 0.5440 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 50/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5644 - sparse_categorical_accuracy: 0.9447 - val_loss: 0.5462 - val_sparse_categorical_accuracy: 0.9563 - learning_rate: 0.0010
# Epoch 51/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5635 - sparse_categorical_accuracy: 0.9309 - val_loss: 0.5386 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 52/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5496 - sparse_categorical_accuracy: 0.9500 - val_loss: 0.5280 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 53/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5351 - sparse_categorical_accuracy: 0.9546 - val_loss: 0.5204 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 54/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5502 - sparse_categorical_accuracy: 0.9435 - val_loss: 0.5253 - val_sparse_categorical_accuracy: 0.8594 - learning_rate: 0.0010
# Epoch 55/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5367 - sparse_categorical_accuracy: 0.9322 - val_loss: 0.5088 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 56/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5245 - sparse_categorical_accuracy: 0.9557 - val_loss: 0.5053 - val_sparse_categorical_accuracy: 0.9641 - learning_rate: 0.0010
# Epoch 57/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5166 - sparse_categorical_accuracy: 0.9505 - val_loss: 0.4923 - val_sparse_categorical_accuracy: 0.9812 - learning_rate: 0.0010
# Epoch 58/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5156 - sparse_categorical_accuracy: 0.9518 - val_loss: 0.4882 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 59/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5097 - sparse_categorical_accuracy: 0.9567 - val_loss: 0.4835 - val_sparse_categorical_accuracy: 0.9812 - learning_rate: 0.0010
# Epoch 60/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5100 - sparse_categorical_accuracy: 0.9448 - val_loss: 0.4762 - val_sparse_categorical_accuracy: 0.9812 - learning_rate: 0.0010
# Epoch 61/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4977 - sparse_categorical_accuracy: 0.9456 - val_loss: 0.4754 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 62/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4821 - sparse_categorical_accuracy: 0.9528 - val_loss: 0.4601 - val_sparse_categorical_accuracy: 0.9812 - learning_rate: 0.0010
# Epoch 63/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4770 - sparse_categorical_accuracy: 0.9589 - val_loss: 0.4762 - val_sparse_categorical_accuracy: 0.9578 - learning_rate: 0.0010
# Epoch 64/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4689 - sparse_categorical_accuracy: 0.9595 - val_loss: 0.4595 - val_sparse_categorical_accuracy: 0.9672 - learning_rate: 0.0010
# Epoch 65/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4595 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.4406 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 66/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4718 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.4351 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 67/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4578 - sparse_categorical_accuracy: 0.9533 - val_loss: 0.4386 - val_sparse_categorical_accuracy: 0.9766 - learning_rate: 0.0010
# Epoch 68/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4579 - sparse_categorical_accuracy: 0.9530 - val_loss: 0.4403 - val_sparse_categorical_accuracy: 0.9703 - learning_rate: 0.0010
# Epoch 69/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4368 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.4158 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 70/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4432 - sparse_categorical_accuracy: 0.9606 - val_loss: 0.4188 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 71/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4248 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.4290 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 72/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4186 - sparse_categorical_accuracy: 0.9672 - val_loss: 0.4098 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 73/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4275 - sparse_categorical_accuracy: 0.9618 - val_loss: 0.3957 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 74/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4197 - sparse_categorical_accuracy: 0.9579 - val_loss: 0.3895 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 75/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4207 - sparse_categorical_accuracy: 0.9595 - val_loss: 0.3844 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 76/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4016 - sparse_categorical_accuracy: 0.9652 - val_loss: 0.3794 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 77/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4129 - sparse_categorical_accuracy: 0.9611 - val_loss: 0.3826 - val_sparse_categorical_accuracy: 0.9703 - learning_rate: 0.0010
# Epoch 78/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3968 - sparse_categorical_accuracy: 0.9579 - val_loss: 0.3794 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 79/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3907 - sparse_categorical_accuracy: 0.9606 - val_loss: 0.3606 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 80/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3862 - sparse_categorical_accuracy: 0.9649 - val_loss: 0.3690 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 81/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3705 - sparse_categorical_accuracy: 0.9672 - val_loss: 0.4058 - val_sparse_categorical_accuracy: 0.9500 - learning_rate: 0.0010
# Epoch 82/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3726 - sparse_categorical_accuracy: 0.9613 - val_loss: 0.3531 - val_sparse_categorical_accuracy: 0.9812 - learning_rate: 0.0010
# Epoch 83/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3736 - sparse_categorical_accuracy: 0.9592 - val_loss: 0.3493 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 84/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3772 - sparse_categorical_accuracy: 0.9546 - val_loss: 0.3473 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 85/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3820 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.3339 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 86/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3448 - sparse_categorical_accuracy: 0.9728 - val_loss: 0.3383 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 87/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3559 - sparse_categorical_accuracy: 0.9652 - val_loss: 0.3248 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 88/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3389 - sparse_categorical_accuracy: 0.9645 - val_loss: 0.3209 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 89/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3372 - sparse_categorical_accuracy: 0.9702 - val_loss: 0.3146 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 90/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3307 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.3111 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 91/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3335 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.3080 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 92/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3331 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.3094 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 93/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3169 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.2994 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 94/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3279 - sparse_categorical_accuracy: 0.9643 - val_loss: 0.2884 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 95/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3191 - sparse_categorical_accuracy: 0.9695 - val_loss: 0.3031 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 96/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3090 - sparse_categorical_accuracy: 0.9690 - val_loss: 0.2835 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 97/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3115 - sparse_categorical_accuracy: 0.9655 - val_loss: 0.2808 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 98/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2970 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.2792 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 99/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2931 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.2801 - val_sparse_categorical_accuracy: 0.9812 - learning_rate: 0.0010
# Epoch 100/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2920 - sparse_categorical_accuracy: 0.9707 - val_loss: 0.2721 - val_sparse_categorical_accuracy: 0.9812 - learning_rate: 0.0010
# Epoch 101/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2866 - sparse_categorical_accuracy: 0.9700 - val_loss: 0.2705 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 102/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2887 - sparse_categorical_accuracy: 0.9666 - val_loss: 0.2692 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 103/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2869 - sparse_categorical_accuracy: 0.9704 - val_loss: 0.2704 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 104/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2803 - sparse_categorical_accuracy: 0.9713 - val_loss: 0.2570 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 105/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2872 - sparse_categorical_accuracy: 0.9616 - val_loss: 0.2631 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 106/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2710 - sparse_categorical_accuracy: 0.9675 - val_loss: 0.2480 - val_sparse_categorical_accuracy: 0.9875 - learning_rate: 0.0010
# Epoch 107/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2625 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.2452 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 108/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2707 - sparse_categorical_accuracy: 0.9640 - val_loss: 0.2406 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 109/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2656 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.2621 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 110/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2549 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.2371 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 111/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2612 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.2307 - val_sparse_categorical_accuracy: 0.9812 - learning_rate: 0.0010
# Epoch 112/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2537 - sparse_categorical_accuracy: 0.9707 - val_loss: 0.2272 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 113/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2497 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.2361 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 114/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2566 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.2324 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 115/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2529 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.2252 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 116/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2408 - sparse_categorical_accuracy: 0.9697 - val_loss: 0.2162 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 117/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2339 - sparse_categorical_accuracy: 0.9741 - val_loss: 0.2119 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 118/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2340 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.2133 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 119/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2308 - sparse_categorical_accuracy: 0.9730 - val_loss: 0.2268 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 120/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2293 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.2095 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 121/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2301 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.2104 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 122/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2222 - sparse_categorical_accuracy: 0.9735 - val_loss: 0.2045 - val_sparse_categorical_accuracy: 0.9766 - learning_rate: 0.0010
# Epoch 123/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2240 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.2088 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 124/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2194 - sparse_categorical_accuracy: 0.9704 - val_loss: 0.2061 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 125/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2175 - sparse_categorical_accuracy: 0.9728 - val_loss: 0.1954 - val_sparse_categorical_accuracy: 0.9875 - learning_rate: 0.0010
# Epoch 126/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2233 - sparse_categorical_accuracy: 0.9629 - val_loss: 0.1987 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 127/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2177 - sparse_categorical_accuracy: 0.9752 - val_loss: 0.2238 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 128/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2133 - sparse_categorical_accuracy: 0.9705 - val_loss: 0.1916 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 129/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1965 - sparse_categorical_accuracy: 0.9754 - val_loss: 0.2023 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 130/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2119 - sparse_categorical_accuracy: 0.9678 - val_loss: 0.1893 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 131/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2116 - sparse_categorical_accuracy: 0.9677 - val_loss: 0.1830 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 132/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2039 - sparse_categorical_accuracy: 0.9723 - val_loss: 0.1803 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 133/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2024 - sparse_categorical_accuracy: 0.9720 - val_loss: 0.1750 - val_sparse_categorical_accuracy: 0.9812 - learning_rate: 0.0010
# Epoch 134/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2010 - sparse_categorical_accuracy: 0.9717 - val_loss: 0.1733 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 135/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2061 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.1751 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 136/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1988 - sparse_categorical_accuracy: 0.9706 - val_loss: 0.1756 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 137/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1983 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.1709 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 138/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1877 - sparse_categorical_accuracy: 0.9745 - val_loss: 0.1651 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 139/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2020 - sparse_categorical_accuracy: 0.9710 - val_loss: 0.1656 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 140/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1836 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.1665 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 141/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1807 - sparse_categorical_accuracy: 0.9762 - val_loss: 0.1740 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 142/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1854 - sparse_categorical_accuracy: 0.9709 - val_loss: 0.1740 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 143/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1876 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.1605 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 144/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1806 - sparse_categorical_accuracy: 0.9702 - val_loss: 0.1615 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 145/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1758 - sparse_categorical_accuracy: 0.9756 - val_loss: 0.1610 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 146/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1841 - sparse_categorical_accuracy: 0.9728 - val_loss: 0.1525 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 147/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1735 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.1532 - val_sparse_categorical_accuracy: 0.9875 - learning_rate: 0.0010
# Epoch 148/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1770 - sparse_categorical_accuracy: 0.9676 - val_loss: 0.1491 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 149/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1682 - sparse_categorical_accuracy: 0.9702 - val_loss: 0.1526 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 150/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1676 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.1503 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010

# %%
# model = keras.saving.load_model("best_model.keras")

# test_loss, test_acc = model.evaluate(x_test, y_test)

# print("Test accuracy", test_acc)
# print("Test loss", test_loss)

# %%
# Load the model
model = keras.saving.load_model("best_model.keras")

# Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1682 - sparse_categorical_accuracy: 0.9780
# Test accuracy: 0.9800000190734863
# Test loss: 0.15565642714500427

# %%
# model info
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 128, 4)         │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 4)         │            16 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 128, 4)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 4)              │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │            20 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 142 (572.00 B)
#  Trainable params: 44 (176.00 B)
#  Non-trainable params: 8 (32.00 B)
#  Optimizer params: 90 (364.00 B)

# %%
import matplotlib.pyplot as plt

# Set font to Times New Roman
plt.rcParams["font.family"] = "Times New Roman"

# Plot training history
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("CNN Classifier Training Curve")
plt.ylabel("Accuracy", fontsize="large")
plt.xlabel("Epoch", fontsize="large")
plt.legend(["Train", "Val"], loc="best")

# Set x-axis limits
plt.xlim(-20, 160)

# Save the figure
plt.savefig("CNN_Classifier.png")

# Show the plot
plt.show()
plt.close()

# %%
# save model
model.save("cnn_model.keras")

# %%
# save x_test, y_test as npy file, this partition is consistent with the partition in the previous step

# x_test save
np.save('x_test.npy', x_test)

print(x_test.shape)

# y_test save, 1-hot encoding first
tmp_y_test = np.zeros((y_test.shape[0], num_classes))
for i in range(y_test.shape[0]):
    tmp_y_test[i][y_test[i][0]] = 1

np.save('y_test.npy', tmp_y_test)

print(tmp_y_test.shape)
# Out:
# (800, 128, 1)
# (800, 4)
