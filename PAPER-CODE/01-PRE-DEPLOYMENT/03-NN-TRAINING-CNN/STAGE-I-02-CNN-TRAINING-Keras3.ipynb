# %% [markdown]
# # CNN FOR EVENT CLASSIFICATION

# %% [markdown]
# ## DATA GENERATION

# %%
# DEPENDENCIES

import numpy as np
import sys
import os
import matplotlib.pyplot as plt
import random
import time
import datetime
import pandas as pd

import prenn # for deep learning

# %%
# RAW DATA
AVPath = '../DATA/SYN_RES/RESPONSE_AV.npy'
EQPath = '../DATA/SYN_RES/RESPONSE_EQ.npy'
IPPath = '../DATA/SYN_RES/RESPONSE_IP.npy'
SWPath = '../DATA/SYN_RES/RESPONSE_SW.npy'

# Load Data + add noise to the data
RESPONSE_AV = np.load(AVPath)
RESPONSE_EQ = np.load(EQPath)
RESPONSE_IP = np.load(IPPath)
RESPONSE_SW = np.load(SWPath)

## only use part of the data
raw_len = RESPONSE_AV.shape[0]
ratio = 1.0 # ALL DATA USED FOR TRAINING
use_len = int(raw_len * ratio)

RESPONSE_AV = RESPONSE_AV[:use_len]
RESPONSE_EQ = RESPONSE_EQ[:use_len]
RESPONSE_IP = RESPONSE_IP[:use_len]
RESPONSE_SW = RESPONSE_SW[:use_len]

## Check Data Info
print(type(RESPONSE_AV))
print('RESPONSE_AV Shape:', RESPONSE_AV.shape)
print(type(RESPONSE_EQ))
print('RESPONSE_EQ Shape:', RESPONSE_EQ.shape)
print(type(RESPONSE_IP))
print('RESPONSE_IP Shape:', RESPONSE_IP.shape)
print(type(RESPONSE_SW))
print('RESPONSE_SW Shape:', RESPONSE_SW.shape)
# Out:
# <class 'numpy.ndarray'>
# RESPONSE_AV Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_EQ Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_IP Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_SW Shape: (1000, 6000)

# %%
## Check Random Data
selected_idx = np.random.randint(RESPONSE_AV.shape[0])

## Plot Random Data - use subplot
plt.figure(figsize=(30, 10))
plt.subplot(2, 2, 1)
plt.plot(RESPONSE_AV[selected_idx, :])
plt.title('AV')
plt.subplot(2, 2, 2)
plt.plot(RESPONSE_EQ[selected_idx, :])
plt.title('EQ')
plt.subplot(2, 2, 3)
plt.plot(RESPONSE_IP[selected_idx, :])
plt.title('IP')
plt.subplot(2, 2, 4)
plt.plot(RESPONSE_SW[selected_idx, :])
plt.title('SW')
plt.show()

# %%
num_type = 4

reshape_shape_0 = RESPONSE_AV.shape[0]
reshape_shape_1 = RESPONSE_AV.shape[1]

LenTS = reshape_shape_1

# %%
# Integrate All Data into a 2D Array

## Reshape Data
RESPONSE_AV_RESHAPED = RESPONSE_AV.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_EQ_RESHAPED = RESPONSE_EQ.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_IP_RESHAPED = RESPONSE_IP.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_SW_RESHAPED = RESPONSE_SW.reshape(reshape_shape_0, reshape_shape_1)

## Stack Data
RESPONSE = np.vstack((RESPONSE_AV_RESHAPED, RESPONSE_EQ_RESHAPED, RESPONSE_IP_RESHAPED, RESPONSE_SW_RESHAPED))

## Total Number of Samples
NumSample = RESPONSE.shape[0]
print('Total Number of Samples:', NumSample)
# Out:
# Total Number of Samples: 4000

# %%
# Real Ground Truth

## Binary Form, Interest or Not
Real_GT_B = np.zeros((RESPONSE.shape[0], 1))

## Real_GT_B, only the first quarter of the data is considered as not interesting
for i in range(RESPONSE_AV.shape[0], RESPONSE.shape[0]):
    Real_GT_B[i] = 1

## plot the binary form
plt.figure()
plt.plot(Real_GT_B)
plt.show()

## Multi-Class Form, Event Type
Real_GT_M = np.zeros((RESPONSE.shape[0], 4))

## Real_GT_M, 4 types of events
for i in range(num_type):
    Real_GT_M[i*reshape_shape_0:(i+1)*reshape_shape_0, i] = 1

## plot the multi-class form, 4 subplots, each subplot for one type of event
plt.figure(figsize=(30, 10))
plt.subplot(4, 1, 1)
plt.plot(Real_GT_M[:, 0])
plt.title('AV')
plt.subplot(4, 1, 2)
plt.plot(Real_GT_M[:, 1])
plt.title('EQ')
plt.subplot(4, 1, 3)
plt.plot(Real_GT_M[:, 2])
plt.title('IP')
plt.subplot(4, 1, 4)
plt.plot(Real_GT_M[:, 3])
plt.title('SW')
plt.show()

# %%
# process parameters

# nn input length
nn_in_len = 128

# time step
dt = 0.01

# nperseg
nperseg = 128

# output length

# %%
NN_IN_DATA = np.zeros((NumSample, nn_in_len))

for i in range(NumSample):
    NN_IN_DATA[i, :] = prenn.prenn(RESPONSE[i, :].reshape(1, -1), dt, nperseg, nn_in_len)

# %%
# check whether nan exists
nan_idx = np.argwhere(np.isnan(NN_IN_DATA))
print(nan_idx)
# Out:
# []

# %%
# plot to check
# selected_idx = np.random.randint(NumSample)
selected_idx = 599
plt.figure()
plt.plot(NN_IN_DATA[selected_idx, :])
plt.show()

# %%
# save data as npy file
np.save('NN_IN_DATA.npy', NN_IN_DATA)

# %%
# LABELS
NN_IN_LABEL = np.zeros((NumSample, 1))
NN_IN_LABEL_1HOT = np.zeros((NumSample, 4))

# %%
# NN_IN_LABEL & NN_IN_LABEL_1HOT
for i in range(NumSample):
    if i < reshape_shape_0:
        NN_IN_LABEL[i] = 0
        NN_IN_LABEL_1HOT[i, 0] = 1
    elif i < reshape_shape_0 * 2:
        NN_IN_LABEL[i] = 1
        NN_IN_LABEL_1HOT[i, 1] = 1
    elif i < reshape_shape_0 * 3:
        NN_IN_LABEL[i] = 2
        NN_IN_LABEL_1HOT[i, 2] = 1
    else:
        NN_IN_LABEL[i] = 3
        NN_IN_LABEL_1HOT[i, 3] = 1

# %%
## plot NN_IN_LABEL
plt.figure()
plt.plot(NN_IN_LABEL)
plt.show()

# %%
## plot NN_IN_LABEL_1HOT
plt.figure(figsize=(30, 10))
plt.subplot(4, 1, 1)
plt.plot(NN_IN_LABEL_1HOT[:, 0])
plt.title('AV')
plt.subplot(4, 1, 2)
plt.plot(NN_IN_LABEL_1HOT[:, 1])
plt.title('EQ')
plt.subplot(4, 1, 3)
plt.plot(NN_IN_LABEL_1HOT[:, 2])
plt.title('IP')
plt.subplot(4, 1, 4)
plt.plot(NN_IN_LABEL_1HOT[:, 3])
plt.title('SW')
plt.show()

# %%
# save data as npy file
np.save('NN_IN_LABEL.npy', NN_IN_LABEL)
np.save('NN_IN_LABEL_1HOT.npy', NN_IN_LABEL_1HOT)

# %% [markdown]
# ## CNN MODEL FOR CLASSIFICATION

# %%
# dependencies
import numpy as np
import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
import tf2onnx
import onnx
# Out:
# WARNING:tensorflow:From C:\Users\cswof\AppData\Roaming\Python\Python312\site-packages\tf2onnx\tf_loader.py:68: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\cswof\AppData\Roaming\Python\Python312\site-packages\tf2onnx\tf_loader.py:72: The name tf.train.import_meta_graph is deprecated. Please use tf.compat.v1.train.import_meta_graph instead.

# %%
# data preparation

data = np.load('NN_IN_DATA.npy')
# expand dimensions to 3D
data = np.expand_dims(data, axis=2)

print(data.shape)

label_1h = np.load('NN_IN_LABEL_1HOT.npy').astype(int)
print(label_1h.shape)

label = np.argmax(label_1h, axis=1).astype(int)
label = label.reshape((-1,1))

print(label.shape)
# Out:
# (4000, 128, 1)
# (4000, 4)
# (4000, 1)

# %%
# split data as x_train, x_test, y_train, y_test
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=42)

# check info
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3200, 128, 1)
# (800, 128, 1)
# (3200, 1)
# (800, 1)

# %%
num_classes = np.unique(label).shape[0]
print(num_classes)
# Out:
# 4

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=4, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    # conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    # conv2 = keras.layers.BatchNormalization()(conv2)
    # conv2 = keras.layers.ReLU()(conv2)

    # conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    # conv3 = keras.layers.BatchNormalization()(conv3)
    # conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv1)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
# keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 150
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.3997 - sparse_categorical_accuracy: 0.2559 - val_loss: 1.3817 - val_sparse_categorical_accuracy: 0.2797 - learning_rate: 0.0010
# Epoch 2/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3815 - sparse_categorical_accuracy: 0.2492 - val_loss: 1.3727 - val_sparse_categorical_accuracy: 0.2891 - learning_rate: 0.0010
# Epoch 3/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3750 - sparse_categorical_accuracy: 0.2413 - val_loss: 1.3660 - val_sparse_categorical_accuracy: 0.2953 - learning_rate: 0.0010
# Epoch 4/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3644 - sparse_categorical_accuracy: 0.2564 - val_loss: 1.3595 - val_sparse_categorical_accuracy: 0.5250 - learning_rate: 0.0010
# Epoch 5/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3542 - sparse_categorical_accuracy: 0.2638 - val_loss: 1.3567 - val_sparse_categorical_accuracy: 0.2594 - learning_rate: 0.0010
# Epoch 6/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3377 - sparse_categorical_accuracy: 0.5312 - val_loss: 1.3433 - val_sparse_categorical_accuracy: 0.3063 - learning_rate: 0.0010
# Epoch 7/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3162 - sparse_categorical_accuracy: 0.7148 - val_loss: 1.3154 - val_sparse_categorical_accuracy: 0.4766 - learning_rate: 0.0010
# Epoch 8/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2897 - sparse_categorical_accuracy: 0.7153 - val_loss: 1.2919 - val_sparse_categorical_accuracy: 0.6687 - learning_rate: 0.0010
# Epoch 9/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2476 - sparse_categorical_accuracy: 0.7032 - val_loss: 1.2555 - val_sparse_categorical_accuracy: 0.7094 - learning_rate: 0.0010
# Epoch 10/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2223 - sparse_categorical_accuracy: 0.6667 - val_loss: 1.2159 - val_sparse_categorical_accuracy: 0.7047 - learning_rate: 0.0010
# Epoch 11/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1862 - sparse_categorical_accuracy: 0.6546 - val_loss: 1.1782 - val_sparse_categorical_accuracy: 0.6969 - learning_rate: 0.0010
# Epoch 12/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1561 - sparse_categorical_accuracy: 0.6736 - val_loss: 1.1435 - val_sparse_categorical_accuracy: 0.6984 - learning_rate: 0.0010
# Epoch 13/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1312 - sparse_categorical_accuracy: 0.6706 - val_loss: 1.1096 - val_sparse_categorical_accuracy: 0.6969 - learning_rate: 0.0010
# Epoch 14/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0910 - sparse_categorical_accuracy: 0.6972 - val_loss: 1.0784 - val_sparse_categorical_accuracy: 0.7000 - learning_rate: 0.0010
# Epoch 15/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0754 - sparse_categorical_accuracy: 0.6862 - val_loss: 1.0488 - val_sparse_categorical_accuracy: 0.7047 - learning_rate: 0.0010
# Epoch 16/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0479 - sparse_categorical_accuracy: 0.6959 - val_loss: 1.0234 - val_sparse_categorical_accuracy: 0.7297 - learning_rate: 0.0010
# Epoch 17/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0130 - sparse_categorical_accuracy: 0.7226 - val_loss: 0.9966 - val_sparse_categorical_accuracy: 0.7281 - learning_rate: 0.0010
# Epoch 18/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9910 - sparse_categorical_accuracy: 0.7978 - val_loss: 0.9712 - val_sparse_categorical_accuracy: 0.9203 - learning_rate: 0.0010
# Epoch 19/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9711 - sparse_categorical_accuracy: 0.8910 - val_loss: 0.9493 - val_sparse_categorical_accuracy: 0.9406 - learning_rate: 0.0010
# Epoch 20/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9492 - sparse_categorical_accuracy: 0.9271 - val_loss: 0.9266 - val_sparse_categorical_accuracy: 0.9453 - learning_rate: 0.0010
# Epoch 21/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9227 - sparse_categorical_accuracy: 0.9321 - val_loss: 0.9056 - val_sparse_categorical_accuracy: 0.8719 - learning_rate: 0.0010
# Epoch 22/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9044 - sparse_categorical_accuracy: 0.8650 - val_loss: 0.8880 - val_sparse_categorical_accuracy: 0.8687 - learning_rate: 0.0010
# Epoch 23/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8850 - sparse_categorical_accuracy: 0.9210 - val_loss: 0.8662 - val_sparse_categorical_accuracy: 0.9234 - learning_rate: 0.0010
# Epoch 24/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8754 - sparse_categorical_accuracy: 0.9186 - val_loss: 0.8505 - val_sparse_categorical_accuracy: 0.9688 - learning_rate: 0.0010
# Epoch 25/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8577 - sparse_categorical_accuracy: 0.9090 - val_loss: 0.8343 - val_sparse_categorical_accuracy: 0.9625 - learning_rate: 0.0010
# Epoch 26/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8433 - sparse_categorical_accuracy: 0.9212 - val_loss: 0.8154 - val_sparse_categorical_accuracy: 0.9672 - learning_rate: 0.0010
# Epoch 27/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8281 - sparse_categorical_accuracy: 0.8551 - val_loss: 0.8003 - val_sparse_categorical_accuracy: 0.9109 - learning_rate: 0.0010
# Epoch 28/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8176 - sparse_categorical_accuracy: 0.9014 - val_loss: 0.7839 - val_sparse_categorical_accuracy: 0.8625 - learning_rate: 0.0010
# Epoch 29/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7979 - sparse_categorical_accuracy: 0.8491 - val_loss: 0.7745 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 30/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7845 - sparse_categorical_accuracy: 0.9140 - val_loss: 0.7594 - val_sparse_categorical_accuracy: 0.9250 - learning_rate: 0.0010
# Epoch 31/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7672 - sparse_categorical_accuracy: 0.9065 - val_loss: 0.7455 - val_sparse_categorical_accuracy: 0.9062 - learning_rate: 0.0010
# Epoch 32/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7634 - sparse_categorical_accuracy: 0.9158 - val_loss: 0.7324 - val_sparse_categorical_accuracy: 0.9203 - learning_rate: 0.0010
# Epoch 33/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7439 - sparse_categorical_accuracy: 0.8815 - val_loss: 0.7212 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 34/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7367 - sparse_categorical_accuracy: 0.8938 - val_loss: 0.7085 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 35/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7256 - sparse_categorical_accuracy: 0.9202 - val_loss: 0.6967 - val_sparse_categorical_accuracy: 0.9062 - learning_rate: 0.0010
# Epoch 36/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7163 - sparse_categorical_accuracy: 0.9264 - val_loss: 0.6874 - val_sparse_categorical_accuracy: 0.8781 - learning_rate: 0.0010
# Epoch 37/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7019 - sparse_categorical_accuracy: 0.9124 - val_loss: 0.6749 - val_sparse_categorical_accuracy: 0.9062 - learning_rate: 0.0010
# Epoch 38/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6932 - sparse_categorical_accuracy: 0.9064 - val_loss: 0.6666 - val_sparse_categorical_accuracy: 0.9453 - learning_rate: 0.0010
# Epoch 39/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6662 - sparse_categorical_accuracy: 0.9263 - val_loss: 0.6558 - val_sparse_categorical_accuracy: 0.9469 - learning_rate: 0.0010
# Epoch 40/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6760 - sparse_categorical_accuracy: 0.9315 - val_loss: 0.6460 - val_sparse_categorical_accuracy: 0.9250 - learning_rate: 0.0010
# Epoch 41/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6580 - sparse_categorical_accuracy: 0.9092 - val_loss: 0.6351 - val_sparse_categorical_accuracy: 0.9625 - learning_rate: 0.0010
# Epoch 42/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6663 - sparse_categorical_accuracy: 0.9270 - val_loss: 0.6262 - val_sparse_categorical_accuracy: 0.9281 - learning_rate: 0.0010
# Epoch 43/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6348 - sparse_categorical_accuracy: 0.9286 - val_loss: 0.6193 - val_sparse_categorical_accuracy: 0.9422 - learning_rate: 0.0010
# Epoch 44/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6519 - sparse_categorical_accuracy: 0.9176 - val_loss: 0.6087 - val_sparse_categorical_accuracy: 0.9469 - learning_rate: 0.0010
# Epoch 45/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6432 - sparse_categorical_accuracy: 0.9247 - val_loss: 0.5995 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 46/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6383 - sparse_categorical_accuracy: 0.9284 - val_loss: 0.5918 - val_sparse_categorical_accuracy: 0.9500 - learning_rate: 0.0010
# Epoch 47/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6160 - sparse_categorical_accuracy: 0.9326 - val_loss: 0.5848 - val_sparse_categorical_accuracy: 0.9656 - learning_rate: 0.0010
# Epoch 48/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6151 - sparse_categorical_accuracy: 0.9352 - val_loss: 0.5752 - val_sparse_categorical_accuracy: 0.9641 - learning_rate: 0.0010
# Epoch 49/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5973 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.5662 - val_sparse_categorical_accuracy: 0.9625 - learning_rate: 0.0010
# Epoch 50/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5882 - sparse_categorical_accuracy: 0.9502 - val_loss: 0.5590 - val_sparse_categorical_accuracy: 0.9672 - learning_rate: 0.0010
# Epoch 51/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5806 - sparse_categorical_accuracy: 0.9394 - val_loss: 0.5520 - val_sparse_categorical_accuracy: 0.9703 - learning_rate: 0.0010
# Epoch 52/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5726 - sparse_categorical_accuracy: 0.9511 - val_loss: 0.5446 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 53/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5733 - sparse_categorical_accuracy: 0.9442 - val_loss: 0.5363 - val_sparse_categorical_accuracy: 0.9688 - learning_rate: 0.0010
# Epoch 54/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5552 - sparse_categorical_accuracy: 0.9528 - val_loss: 0.5287 - val_sparse_categorical_accuracy: 0.9672 - learning_rate: 0.0010
# Epoch 55/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5477 - sparse_categorical_accuracy: 0.9613 - val_loss: 0.5201 - val_sparse_categorical_accuracy: 0.9672 - learning_rate: 0.0010
# Epoch 56/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5565 - sparse_categorical_accuracy: 0.9537 - val_loss: 0.5162 - val_sparse_categorical_accuracy: 0.9703 - learning_rate: 0.0010
# Epoch 57/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5433 - sparse_categorical_accuracy: 0.9571 - val_loss: 0.5074 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 58/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5363 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.5024 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 59/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5416 - sparse_categorical_accuracy: 0.9498 - val_loss: 0.4920 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 60/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5223 - sparse_categorical_accuracy: 0.9596 - val_loss: 0.4874 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 61/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5062 - sparse_categorical_accuracy: 0.9617 - val_loss: 0.4817 - val_sparse_categorical_accuracy: 0.9781 - learning_rate: 0.0010
# Epoch 62/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5228 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.4754 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 63/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4959 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.4703 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 64/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4982 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.4628 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 65/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4841 - sparse_categorical_accuracy: 0.9672 - val_loss: 0.4585 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 66/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4814 - sparse_categorical_accuracy: 0.9636 - val_loss: 0.4518 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 67/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4724 - sparse_categorical_accuracy: 0.9716 - val_loss: 0.4450 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 68/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4658 - sparse_categorical_accuracy: 0.9702 - val_loss: 0.4387 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 69/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4733 - sparse_categorical_accuracy: 0.9633 - val_loss: 0.4315 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 70/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4439 - sparse_categorical_accuracy: 0.9727 - val_loss: 0.4298 - val_sparse_categorical_accuracy: 0.9812 - learning_rate: 0.0010
# Epoch 71/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4558 - sparse_categorical_accuracy: 0.9624 - val_loss: 0.4221 - val_sparse_categorical_accuracy: 0.9812 - learning_rate: 0.0010
# Epoch 72/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4365 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.4164 - val_sparse_categorical_accuracy: 0.9812 - learning_rate: 0.0010
# Epoch 73/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4256 - sparse_categorical_accuracy: 0.9752 - val_loss: 0.4094 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 74/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4296 - sparse_categorical_accuracy: 0.9742 - val_loss: 0.4036 - val_sparse_categorical_accuracy: 0.9797 - learning_rate: 0.0010
# Epoch 75/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4279 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.4003 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 76/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4315 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.3948 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 77/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4239 - sparse_categorical_accuracy: 0.9706 - val_loss: 0.3892 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 78/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4230 - sparse_categorical_accuracy: 0.9656 - val_loss: 0.3858 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 79/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4142 - sparse_categorical_accuracy: 0.9730 - val_loss: 0.3822 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 80/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4091 - sparse_categorical_accuracy: 0.9673 - val_loss: 0.3742 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 81/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4000 - sparse_categorical_accuracy: 0.9730 - val_loss: 0.3718 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 82/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4017 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.3677 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 83/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3806 - sparse_categorical_accuracy: 0.9766 - val_loss: 0.3610 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 84/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3877 - sparse_categorical_accuracy: 0.9676 - val_loss: 0.3557 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 85/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3910 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.3507 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 86/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3755 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.3441 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 87/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3803 - sparse_categorical_accuracy: 0.9718 - val_loss: 0.3415 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 88/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3661 - sparse_categorical_accuracy: 0.9723 - val_loss: 0.3357 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 89/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3599 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.3315 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 90/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3524 - sparse_categorical_accuracy: 0.9737 - val_loss: 0.3331 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 91/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3506 - sparse_categorical_accuracy: 0.9717 - val_loss: 0.3227 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 92/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3391 - sparse_categorical_accuracy: 0.9763 - val_loss: 0.3174 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 93/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3599 - sparse_categorical_accuracy: 0.9649 - val_loss: 0.3153 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 94/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3322 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.3194 - val_sparse_categorical_accuracy: 0.9812 - learning_rate: 0.0010
# Epoch 95/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3400 - sparse_categorical_accuracy: 0.9710 - val_loss: 0.3073 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 96/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3357 - sparse_categorical_accuracy: 0.9713 - val_loss: 0.3018 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 97/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3315 - sparse_categorical_accuracy: 0.9768 - val_loss: 0.2970 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 98/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3404 - sparse_categorical_accuracy: 0.9711 - val_loss: 0.2943 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 99/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3311 - sparse_categorical_accuracy: 0.9727 - val_loss: 0.2905 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 100/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3228 - sparse_categorical_accuracy: 0.9724 - val_loss: 0.2898 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 101/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3048 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.2842 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 102/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3116 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.2787 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 103/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3074 - sparse_categorical_accuracy: 0.9718 - val_loss: 0.2755 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 104/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3070 - sparse_categorical_accuracy: 0.9678 - val_loss: 0.2711 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 105/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2847 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.2729 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 106/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3015 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.2672 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 107/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2856 - sparse_categorical_accuracy: 0.9754 - val_loss: 0.2621 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 108/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2798 - sparse_categorical_accuracy: 0.9786 - val_loss: 0.2609 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 109/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2852 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.2564 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 110/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2881 - sparse_categorical_accuracy: 0.9755 - val_loss: 0.2569 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 111/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2741 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.2501 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 112/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2770 - sparse_categorical_accuracy: 0.9783 - val_loss: 0.2469 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 113/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2852 - sparse_categorical_accuracy: 0.9739 - val_loss: 0.2440 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 114/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2804 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.2402 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 115/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2644 - sparse_categorical_accuracy: 0.9766 - val_loss: 0.2363 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 116/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2636 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.2338 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 117/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2628 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.2319 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 118/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2498 - sparse_categorical_accuracy: 0.9798 - val_loss: 0.2285 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 119/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2435 - sparse_categorical_accuracy: 0.9817 - val_loss: 0.2264 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 120/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2505 - sparse_categorical_accuracy: 0.9807 - val_loss: 0.2241 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 121/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2510 - sparse_categorical_accuracy: 0.9761 - val_loss: 0.2212 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 122/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2610 - sparse_categorical_accuracy: 0.9770 - val_loss: 0.2183 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 123/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2514 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.2145 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 124/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2485 - sparse_categorical_accuracy: 0.9765 - val_loss: 0.2174 - val_sparse_categorical_accuracy: 0.9891 - learning_rate: 0.0010
# Epoch 125/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2402 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.2155 - val_sparse_categorical_accuracy: 0.9875 - learning_rate: 0.0010
# Epoch 126/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2405 - sparse_categorical_accuracy: 0.9784 - val_loss: 0.2086 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 127/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2178 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.2086 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 128/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2308 - sparse_categorical_accuracy: 0.9752 - val_loss: 0.2071 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 129/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2316 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.2039 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 130/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2275 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.2030 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 131/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2290 - sparse_categorical_accuracy: 0.9754 - val_loss: 0.1997 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 132/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2287 - sparse_categorical_accuracy: 0.9772 - val_loss: 0.1965 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 133/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2284 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.1949 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 134/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2144 - sparse_categorical_accuracy: 0.9841 - val_loss: 0.1912 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 135/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2118 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1914 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 136/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2059 - sparse_categorical_accuracy: 0.9784 - val_loss: 0.1933 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 137/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2270 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.1906 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 138/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2196 - sparse_categorical_accuracy: 0.9808 - val_loss: 0.1846 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 139/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2227 - sparse_categorical_accuracy: 0.9734 - val_loss: 0.1831 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 140/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2166 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1813 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 141/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2031 - sparse_categorical_accuracy: 0.9779 - val_loss: 0.1770 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 142/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1970 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.1771 - val_sparse_categorical_accuracy: 0.9875 - learning_rate: 0.0010
# Epoch 143/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1995 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.1817 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 144/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2117 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.1837 - val_sparse_categorical_accuracy: 0.9828 - learning_rate: 0.0010
# Epoch 145/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1942 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.1720 - val_sparse_categorical_accuracy: 0.9875 - learning_rate: 0.0010
# Epoch 146/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1935 - sparse_categorical_accuracy: 0.9817 - val_loss: 0.1694 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010
# Epoch 147/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1864 - sparse_categorical_accuracy: 0.9828 - val_loss: 0.1683 - val_sparse_categorical_accuracy: 0.9875 - learning_rate: 0.0010
# Epoch 148/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1971 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.1676 - val_sparse_categorical_accuracy: 0.9859 - learning_rate: 0.0010
# Epoch 149/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1975 - sparse_categorical_accuracy: 0.9801 - val_loss: 0.1652 - val_sparse_categorical_accuracy: 0.9875 - learning_rate: 0.0010
# Epoch 150/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1872 - sparse_categorical_accuracy: 0.9801 - val_loss: 0.1644 - val_sparse_categorical_accuracy: 0.9844 - learning_rate: 0.0010

# %%
# model = keras.saving.load_model("best_model.keras")

# test_loss, test_acc = model.evaluate(x_test, y_test)

# print("Test accuracy", test_acc)
# print("Test loss", test_loss)

# %%
# Load the model
model = keras.saving.load_model("best_model.keras")

# Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1747 - sparse_categorical_accuracy: 0.9836
# Test accuracy: 0.9825000166893005
# Test loss: 0.17892733216285706

# %%
# model info
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 128, 4)         │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 4)         │            16 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 128, 4)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 4)              │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │            20 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 142 (572.00 B)
#  Trainable params: 44 (176.00 B)
#  Non-trainable params: 8 (32.00 B)
#  Optimizer params: 90 (364.00 B)

# %%
import matplotlib.pyplot as plt

# Set font to Times New Roman
plt.rcParams["font.family"] = "Times New Roman"

# Plot training history
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel("accuracy", fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")

# Set x-axis limits
plt.xlim(-20, 160)

# Save the figure
plt.savefig("CNN_Classifier.png")

# Show the plot
plt.show()
plt.close()

# %%
# save model
model.save("cnn_model.keras")

# %%
import matplotlib.pyplot as plt

# Set font to Times New Roman
plt.rcParams["font.family"] = "Times New Roman"

# Plot training history
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("CNN Classifier Training Curve")
plt.ylabel("Accuracy", fontsize="large")
plt.xlabel("Epoch", fontsize="large")
plt.legend(["Train", "Val"], loc="best")

# Set x-axis limits
plt.xlim(-20, 160)

# Save the figure
plt.savefig("CNN_Classifier.png")

# Show the plot
plt.show()
plt.close()

# %%
# save x_test, y_test as npy file, this partition is consistent with the partition in the previous step

# x_test save
np.save('x_test.npy', x_test)

print(x_test.shape)

# y_test save, 1-hot encoding first
tmp_y_test = np.zeros((y_test.shape[0], num_classes))
for i in range(y_test.shape[0]):
    tmp_y_test[i][y_test[i][0]] = 1

np.save('y_test.npy', tmp_y_test)

print(tmp_y_test.shape)
# Out:
# (800, 128, 1)
# (800, 4)
