# %% [markdown]
# # CNN FOR EVENT CLASSIFICATION

# %% [markdown]
# ## DATA GENERATION

# %%
# DEPENDENCIES

import numpy as np
import sys
import os
import matplotlib.pyplot as plt
import random
import time
import datetime
import pandas as pd

import prenn # for deep learning

# %%
# RAW DATA
AVPath = '../DATA/SYN_RES/RESPONSE_AV.npy'
EQPath = '../DATA/SYN_RES/RESPONSE_EQ.npy'
IPPath = '../DATA/SYN_RES/RESPONSE_IP.npy'
SWPath = '../DATA/SYN_RES/RESPONSE_SW.npy'

# Load Data + add noise to the data
RESPONSE_AV = np.load(AVPath)
RESPONSE_EQ = np.load(EQPath)
RESPONSE_IP = np.load(IPPath)
RESPONSE_SW = np.load(SWPath)

## only use part of the data
raw_len = RESPONSE_AV.shape[0]
ratio = 1.0 # ALL DATA USED FOR TRAINING
use_len = int(raw_len * ratio)

RESPONSE_AV = RESPONSE_AV[:use_len]
RESPONSE_EQ = RESPONSE_EQ[:use_len]
RESPONSE_IP = RESPONSE_IP[:use_len]
RESPONSE_SW = RESPONSE_SW[:use_len]

## Check Data Info
print(type(RESPONSE_AV))
print('RESPONSE_AV Shape:', RESPONSE_AV.shape)
print(type(RESPONSE_EQ))
print('RESPONSE_EQ Shape:', RESPONSE_EQ.shape)
print(type(RESPONSE_IP))
print('RESPONSE_IP Shape:', RESPONSE_IP.shape)
print(type(RESPONSE_SW))
print('RESPONSE_SW Shape:', RESPONSE_SW.shape)
# Out:
# <class 'numpy.ndarray'>
# RESPONSE_AV Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_EQ Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_IP Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_SW Shape: (1000, 6000)

# %%
## Check Random Data
selected_idx = np.random.randint(RESPONSE_AV.shape[0])

## Plot Random Data - use subplot
plt.figure(figsize=(30, 10))
plt.subplot(2, 2, 1)
plt.plot(RESPONSE_AV[selected_idx, :])
plt.title('AV')
plt.subplot(2, 2, 2)
plt.plot(RESPONSE_EQ[selected_idx, :])
plt.title('EQ')
plt.subplot(2, 2, 3)
plt.plot(RESPONSE_IP[selected_idx, :])
plt.title('IP')
plt.subplot(2, 2, 4)
plt.plot(RESPONSE_SW[selected_idx, :])
plt.title('SW')
plt.show()

# %%
num_type = 4

reshape_shape_0 = RESPONSE_AV.shape[0]
reshape_shape_1 = RESPONSE_AV.shape[1]

LenTS = reshape_shape_1

# %%
# Integrate All Data into a 2D Array

## Reshape Data
RESPONSE_AV_RESHAPED = RESPONSE_AV.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_EQ_RESHAPED = RESPONSE_EQ.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_IP_RESHAPED = RESPONSE_IP.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_SW_RESHAPED = RESPONSE_SW.reshape(reshape_shape_0, reshape_shape_1)

## Stack Data
RESPONSE = np.vstack((RESPONSE_AV_RESHAPED, RESPONSE_EQ_RESHAPED, RESPONSE_IP_RESHAPED, RESPONSE_SW_RESHAPED))

## Total Number of Samples
NumSample = RESPONSE.shape[0]
print('Total Number of Samples:', NumSample)
# Out:
# Total Number of Samples: 4000

# %%
# Real Ground Truth

## Binary Form, Interest or Not
Real_GT_B = np.zeros((RESPONSE.shape[0], 1))

## Real_GT_B, only the first quarter of the data is considered as not interesting
for i in range(RESPONSE_AV.shape[0], RESPONSE.shape[0]):
    Real_GT_B[i] = 1

## plot the binary form
plt.figure()
plt.plot(Real_GT_B)
plt.show()

## Multi-Class Form, Event Type
Real_GT_M = np.zeros((RESPONSE.shape[0], 4))

## Real_GT_M, 4 types of events
for i in range(num_type):
    Real_GT_M[i*reshape_shape_0:(i+1)*reshape_shape_0, i] = 1

## plot the multi-class form, 4 subplots, each subplot for one type of event
plt.figure(figsize=(30, 10))
plt.subplot(4, 1, 1)
plt.plot(Real_GT_M[:, 0])
plt.title('AV')
plt.subplot(4, 1, 2)
plt.plot(Real_GT_M[:, 1])
plt.title('EQ')
plt.subplot(4, 1, 3)
plt.plot(Real_GT_M[:, 2])
plt.title('IP')
plt.subplot(4, 1, 4)
plt.plot(Real_GT_M[:, 3])
plt.title('SW')
plt.show()

# %%
# process parameters

# nn input length
nn_in_len = 128

# time step
dt = 0.01

# nperseg
nperseg = 128

# output length

# %%
NN_IN_DATA = np.zeros((NumSample, nn_in_len))

for i in range(NumSample):
    NN_IN_DATA[i, :] = prenn.prenn(RESPONSE[i, :].reshape(1, -1), dt, nperseg, nn_in_len)

# %%
# check whether nan exists
nan_idx = np.argwhere(np.isnan(NN_IN_DATA))
print(nan_idx)
# Out:
# []

# %%
# plot to check
# selected_idx = np.random.randint(NumSample)
selected_idx = 599
plt.figure()
plt.plot(NN_IN_DATA[selected_idx, :])
plt.show()

# %%
# save data as npy file
np.save('NN_IN_DATA.npy', NN_IN_DATA)

# %%
# LABELS
NN_IN_LABEL = np.zeros((NumSample, 1))
NN_IN_LABEL_1HOT = np.zeros((NumSample, 4))

# %%
# NN_IN_LABEL & NN_IN_LABEL_1HOT
for i in range(NumSample):
    if i < reshape_shape_0:
        NN_IN_LABEL[i] = 0
        NN_IN_LABEL_1HOT[i, 0] = 1
    elif i < reshape_shape_0 * 2:
        NN_IN_LABEL[i] = 1
        NN_IN_LABEL_1HOT[i, 1] = 1
    elif i < reshape_shape_0 * 3:
        NN_IN_LABEL[i] = 2
        NN_IN_LABEL_1HOT[i, 2] = 1
    else:
        NN_IN_LABEL[i] = 3
        NN_IN_LABEL_1HOT[i, 3] = 1

# %%
## plot NN_IN_LABEL
plt.figure()
plt.plot(NN_IN_LABEL)
plt.show()

# %%
## plot NN_IN_LABEL_1HOT
plt.figure(figsize=(30, 10))
plt.subplot(4, 1, 1)
plt.plot(NN_IN_LABEL_1HOT[:, 0])
plt.title('AV')
plt.subplot(4, 1, 2)
plt.plot(NN_IN_LABEL_1HOT[:, 1])
plt.title('EQ')
plt.subplot(4, 1, 3)
plt.plot(NN_IN_LABEL_1HOT[:, 2])
plt.title('IP')
plt.subplot(4, 1, 4)
plt.plot(NN_IN_LABEL_1HOT[:, 3])
plt.title('SW')
plt.show()

# %%
# save data as npy file
np.save('NN_IN_LABEL.npy', NN_IN_LABEL)
np.save('NN_IN_LABEL_1HOT.npy', NN_IN_LABEL_1HOT)

# %% [markdown]
# ## CNN MODEL FOR CLASSIFICATION

# %%
# dependencies
import numpy as np
import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
import tf2onnx
import onnx

# %%
# data preparation

data = np.load('NN_IN_DATA.npy')
# expand dimensions to 3D
data = np.expand_dims(data, axis=2)

print(data.shape)

label_1h = np.load('NN_IN_LABEL_1HOT.npy').astype(int)
print(label_1h.shape)

label = np.argmax(label_1h, axis=1).astype(int)
label = label.reshape((-1,1))

print(label.shape)
# Out:
# (4000, 128, 1)
# (4000, 4)
# (4000, 1)

# %%
# split data as x_train, x_test, y_train, y_test
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=42)

# check info
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3200, 128, 1)
# (800, 128, 1)
# (3200, 1)
# (800, 1)

# %%
num_classes = np.unique(label).shape[0]
print(num_classes)
# Out:
# 4

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=4, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    # conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    # conv2 = keras.layers.BatchNormalization()(conv2)
    # conv2 = keras.layers.ReLU()(conv2)

    # conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    # conv3 = keras.layers.BatchNormalization()(conv3)
    # conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv1)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
# keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 150
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/150
# 80/80 [==============================] - 5s 53ms/step - loss: 1.4321 - sparse_categorical_accuracy: 0.2406 - val_loss: 1.3927 - val_sparse_categorical_accuracy: 0.2625 - lr: 0.0010
# Epoch 2/150
# 80/80 [==============================] - 3s 41ms/step - loss: 1.3697 - sparse_categorical_accuracy: 0.3219 - val_loss: 1.3639 - val_sparse_categorical_accuracy: 0.2891 - lr: 0.0010
# Epoch 3/150
# 80/80 [==============================] - 3s 31ms/step - loss: 1.3418 - sparse_categorical_accuracy: 0.4578 - val_loss: 1.3449 - val_sparse_categorical_accuracy: 0.4906 - lr: 0.0010
# Epoch 4/150
# 80/80 [==============================] - 3s 38ms/step - loss: 1.3171 - sparse_categorical_accuracy: 0.4184 - val_loss: 1.3175 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0010
# Epoch 5/150
# 80/80 [==============================] - 2s 30ms/step - loss: 1.2807 - sparse_categorical_accuracy: 0.5082 - val_loss: 1.2847 - val_sparse_categorical_accuracy: 0.4828 - lr: 0.0010
# Epoch 6/150
# 80/80 [==============================] - 3s 43ms/step - loss: 1.2540 - sparse_categorical_accuracy: 0.5441 - val_loss: 1.2550 - val_sparse_categorical_accuracy: 0.4859 - lr: 0.0010
# Epoch 7/150
# 80/80 [==============================] - 3s 43ms/step - loss: 1.2288 - sparse_categorical_accuracy: 0.5738 - val_loss: 1.2231 - val_sparse_categorical_accuracy: 0.5672 - lr: 0.0010
# Epoch 8/150
# 80/80 [==============================] - 3s 41ms/step - loss: 1.2030 - sparse_categorical_accuracy: 0.5844 - val_loss: 1.1926 - val_sparse_categorical_accuracy: 0.6031 - lr: 0.0010
# Epoch 9/150
# 80/80 [==============================] - 3s 43ms/step - loss: 1.1746 - sparse_categorical_accuracy: 0.6000 - val_loss: 1.1636 - val_sparse_categorical_accuracy: 0.6297 - lr: 0.0010
# Epoch 10/150
# 80/80 [==============================] - 3s 41ms/step - loss: 1.1476 - sparse_categorical_accuracy: 0.6145 - val_loss: 1.1356 - val_sparse_categorical_accuracy: 0.6844 - lr: 0.0010
# Epoch 11/150
# 80/80 [==============================] - 3s 38ms/step - loss: 1.1181 - sparse_categorical_accuracy: 0.6426 - val_loss: 1.1065 - val_sparse_categorical_accuracy: 0.6609 - lr: 0.0010
# Epoch 12/150
# 80/80 [==============================] - 3s 42ms/step - loss: 1.0933 - sparse_categorical_accuracy: 0.6434 - val_loss: 1.0804 - val_sparse_categorical_accuracy: 0.6562 - lr: 0.0010
# Epoch 13/150
# 80/80 [==============================] - 3s 41ms/step - loss: 1.0657 - sparse_categorical_accuracy: 0.6605 - val_loss: 1.0553 - val_sparse_categorical_accuracy: 0.6516 - lr: 0.0010
# Epoch 14/150
# 80/80 [==============================] - 3s 38ms/step - loss: 1.0396 - sparse_categorical_accuracy: 0.6738 - val_loss: 1.0317 - val_sparse_categorical_accuracy: 0.6562 - lr: 0.0010
# Epoch 15/150
# 80/80 [==============================] - 3s 43ms/step - loss: 1.0157 - sparse_categorical_accuracy: 0.6703 - val_loss: 1.0077 - val_sparse_categorical_accuracy: 0.6547 - lr: 0.0010
# Epoch 16/150
# 80/80 [==============================] - 4s 44ms/step - loss: 0.9905 - sparse_categorical_accuracy: 0.6855 - val_loss: 0.9844 - val_sparse_categorical_accuracy: 0.6891 - lr: 0.0010
# Epoch 17/150
# 80/80 [==============================] - 3s 40ms/step - loss: 0.9650 - sparse_categorical_accuracy: 0.6898 - val_loss: 0.9653 - val_sparse_categorical_accuracy: 0.6938 - lr: 0.0010
# Epoch 18/150
# 80/80 [==============================] - 3s 41ms/step - loss: 0.9468 - sparse_categorical_accuracy: 0.6980 - val_loss: 0.9476 - val_sparse_categorical_accuracy: 0.7094 - lr: 0.0010
# Epoch 19/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.9253 - sparse_categorical_accuracy: 0.6953 - val_loss: 0.9249 - val_sparse_categorical_accuracy: 0.7219 - lr: 0.0010
# Epoch 20/150
# 80/80 [==============================] - 3s 40ms/step - loss: 0.9032 - sparse_categorical_accuracy: 0.7031 - val_loss: 0.9099 - val_sparse_categorical_accuracy: 0.7203 - lr: 0.0010
# Epoch 21/150
# 80/80 [==============================] - 3s 44ms/step - loss: 0.8867 - sparse_categorical_accuracy: 0.7113 - val_loss: 0.8916 - val_sparse_categorical_accuracy: 0.7266 - lr: 0.0010
# Epoch 22/150
# 80/80 [==============================] - 3s 38ms/step - loss: 0.8667 - sparse_categorical_accuracy: 0.7172 - val_loss: 0.8761 - val_sparse_categorical_accuracy: 0.7266 - lr: 0.0010
# Epoch 23/150
# 80/80 [==============================] - 3s 35ms/step - loss: 0.8505 - sparse_categorical_accuracy: 0.7391 - val_loss: 0.8549 - val_sparse_categorical_accuracy: 0.7328 - lr: 0.0010
# Epoch 24/150
# 80/80 [==============================] - 3s 41ms/step - loss: 0.8405 - sparse_categorical_accuracy: 0.7363 - val_loss: 0.8442 - val_sparse_categorical_accuracy: 0.7594 - lr: 0.0010
# Epoch 25/150
# 80/80 [==============================] - 3s 39ms/step - loss: 0.8205 - sparse_categorical_accuracy: 0.7621 - val_loss: 0.8293 - val_sparse_categorical_accuracy: 0.8203 - lr: 0.0010
# Epoch 26/150
# 80/80 [==============================] - 3s 40ms/step - loss: 0.8091 - sparse_categorical_accuracy: 0.7457 - val_loss: 0.8144 - val_sparse_categorical_accuracy: 0.7391 - lr: 0.0010
# Epoch 27/150
# 80/80 [==============================] - 3s 38ms/step - loss: 0.7950 - sparse_categorical_accuracy: 0.7824 - val_loss: 0.7998 - val_sparse_categorical_accuracy: 0.7437 - lr: 0.0010
# Epoch 28/150
# 80/80 [==============================] - 3s 38ms/step - loss: 0.7876 - sparse_categorical_accuracy: 0.7707 - val_loss: 0.7942 - val_sparse_categorical_accuracy: 0.8969 - lr: 0.0010
# Epoch 29/150
# 80/80 [==============================] - 5s 58ms/step - loss: 0.7706 - sparse_categorical_accuracy: 0.7973 - val_loss: 0.7787 - val_sparse_categorical_accuracy: 0.9109 - lr: 0.0010
# Epoch 30/150
# 80/80 [==============================] - 4s 44ms/step - loss: 0.7603 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.7645 - val_sparse_categorical_accuracy: 0.9109 - lr: 0.0010
# Epoch 31/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.7497 - sparse_categorical_accuracy: 0.7926 - val_loss: 0.7528 - val_sparse_categorical_accuracy: 0.8219 - lr: 0.0010
# Epoch 32/150
# 80/80 [==============================] - 4s 44ms/step - loss: 0.7399 - sparse_categorical_accuracy: 0.8449 - val_loss: 0.7469 - val_sparse_categorical_accuracy: 0.8062 - lr: 0.0010
# Epoch 33/150
# 80/80 [==============================] - 4s 49ms/step - loss: 0.7297 - sparse_categorical_accuracy: 0.8234 - val_loss: 0.7417 - val_sparse_categorical_accuracy: 0.7875 - lr: 0.0010
# Epoch 34/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.7166 - sparse_categorical_accuracy: 0.8582 - val_loss: 0.7260 - val_sparse_categorical_accuracy: 0.9094 - lr: 0.0010
# Epoch 35/150
# 80/80 [==============================] - 3s 41ms/step - loss: 0.7125 - sparse_categorical_accuracy: 0.8492 - val_loss: 0.7159 - val_sparse_categorical_accuracy: 0.7672 - lr: 0.0010
# Epoch 36/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.7001 - sparse_categorical_accuracy: 0.8527 - val_loss: 0.7056 - val_sparse_categorical_accuracy: 0.9234 - lr: 0.0010
# Epoch 37/150
# 80/80 [==============================] - 4s 49ms/step - loss: 0.6930 - sparse_categorical_accuracy: 0.8512 - val_loss: 0.6986 - val_sparse_categorical_accuracy: 0.9312 - lr: 0.0010
# Epoch 38/150
# 80/80 [==============================] - 4s 46ms/step - loss: 0.6914 - sparse_categorical_accuracy: 0.8660 - val_loss: 0.6894 - val_sparse_categorical_accuracy: 0.9234 - lr: 0.0010
# Epoch 39/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6730 - sparse_categorical_accuracy: 0.8801 - val_loss: 0.6791 - val_sparse_categorical_accuracy: 0.9344 - lr: 0.0010
# Epoch 40/150
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6672 - sparse_categorical_accuracy: 0.8949 - val_loss: 0.6724 - val_sparse_categorical_accuracy: 0.9375 - lr: 0.0010
# Epoch 41/150
# 80/80 [==============================] - 4s 46ms/step - loss: 0.6580 - sparse_categorical_accuracy: 0.8809 - val_loss: 0.6607 - val_sparse_categorical_accuracy: 0.9219 - lr: 0.0010
# Epoch 42/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.6550 - sparse_categorical_accuracy: 0.9027 - val_loss: 0.6546 - val_sparse_categorical_accuracy: 0.7984 - lr: 0.0010
# Epoch 43/150
# 80/80 [==============================] - 4s 46ms/step - loss: 0.6468 - sparse_categorical_accuracy: 0.8918 - val_loss: 0.6442 - val_sparse_categorical_accuracy: 0.8188 - lr: 0.0010
# Epoch 44/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.6366 - sparse_categorical_accuracy: 0.9066 - val_loss: 0.6445 - val_sparse_categorical_accuracy: 0.7734 - lr: 0.0010
# Epoch 45/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.6288 - sparse_categorical_accuracy: 0.9016 - val_loss: 0.6282 - val_sparse_categorical_accuracy: 0.8813 - lr: 0.0010
# Epoch 46/150
# 80/80 [==============================] - 3s 41ms/step - loss: 0.6230 - sparse_categorical_accuracy: 0.9105 - val_loss: 0.6314 - val_sparse_categorical_accuracy: 0.9563 - lr: 0.0010
# Epoch 47/150
# 80/80 [==============================] - 4s 45ms/step - loss: 0.6141 - sparse_categorical_accuracy: 0.9113 - val_loss: 0.6153 - val_sparse_categorical_accuracy: 0.9156 - lr: 0.0010
# Epoch 48/150
# 80/80 [==============================] - 4s 44ms/step - loss: 0.6034 - sparse_categorical_accuracy: 0.9145 - val_loss: 0.6112 - val_sparse_categorical_accuracy: 0.9406 - lr: 0.0010
# Epoch 49/150
# 80/80 [==============================] - 4s 44ms/step - loss: 0.5997 - sparse_categorical_accuracy: 0.9270 - val_loss: 0.6012 - val_sparse_categorical_accuracy: 0.9422 - lr: 0.0010
# Epoch 50/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.5920 - sparse_categorical_accuracy: 0.9273 - val_loss: 0.6013 - val_sparse_categorical_accuracy: 0.9594 - lr: 0.0010
# Epoch 51/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.5879 - sparse_categorical_accuracy: 0.9359 - val_loss: 0.5925 - val_sparse_categorical_accuracy: 0.9266 - lr: 0.0010
# Epoch 52/150
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5782 - sparse_categorical_accuracy: 0.9152 - val_loss: 0.5864 - val_sparse_categorical_accuracy: 0.8875 - lr: 0.0010
# Epoch 53/150
# 80/80 [==============================] - 4s 45ms/step - loss: 0.5745 - sparse_categorical_accuracy: 0.9320 - val_loss: 0.5752 - val_sparse_categorical_accuracy: 0.9531 - lr: 0.0010
# Epoch 54/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.5661 - sparse_categorical_accuracy: 0.9266 - val_loss: 0.5808 - val_sparse_categorical_accuracy: 0.9078 - lr: 0.0010
# Epoch 55/150
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5537 - sparse_categorical_accuracy: 0.9418 - val_loss: 0.5662 - val_sparse_categorical_accuracy: 0.9344 - lr: 0.0010
# Epoch 56/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.5507 - sparse_categorical_accuracy: 0.9453 - val_loss: 0.5563 - val_sparse_categorical_accuracy: 0.9422 - lr: 0.0010
# Epoch 57/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.5434 - sparse_categorical_accuracy: 0.9426 - val_loss: 0.5524 - val_sparse_categorical_accuracy: 0.9563 - lr: 0.0010
# Epoch 58/150
# 80/80 [==============================] - 3s 32ms/step - loss: 0.5410 - sparse_categorical_accuracy: 0.9441 - val_loss: 0.5636 - val_sparse_categorical_accuracy: 0.9203 - lr: 0.0010
# Epoch 59/150
# 80/80 [==============================] - 3s 36ms/step - loss: 0.5316 - sparse_categorical_accuracy: 0.9387 - val_loss: 0.5426 - val_sparse_categorical_accuracy: 0.9469 - lr: 0.0010
# Epoch 60/150
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5227 - sparse_categorical_accuracy: 0.9453 - val_loss: 0.5303 - val_sparse_categorical_accuracy: 0.9609 - lr: 0.0010
# Epoch 61/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.5213 - sparse_categorical_accuracy: 0.9477 - val_loss: 0.5219 - val_sparse_categorical_accuracy: 0.9531 - lr: 0.0010
# Epoch 62/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.5161 - sparse_categorical_accuracy: 0.9480 - val_loss: 0.5114 - val_sparse_categorical_accuracy: 0.9484 - lr: 0.0010
# Epoch 63/150
# 80/80 [==============================] - 3s 41ms/step - loss: 0.5099 - sparse_categorical_accuracy: 0.9523 - val_loss: 0.5069 - val_sparse_categorical_accuracy: 0.9547 - lr: 0.0010
# Epoch 64/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.4975 - sparse_categorical_accuracy: 0.9508 - val_loss: 0.5064 - val_sparse_categorical_accuracy: 0.9609 - lr: 0.0010
# Epoch 65/150
# 80/80 [==============================] - 4s 44ms/step - loss: 0.4971 - sparse_categorical_accuracy: 0.9430 - val_loss: 0.4943 - val_sparse_categorical_accuracy: 0.9547 - lr: 0.0010
# Epoch 66/150
# 80/80 [==============================] - 3s 40ms/step - loss: 0.4863 - sparse_categorical_accuracy: 0.9488 - val_loss: 0.4897 - val_sparse_categorical_accuracy: 0.9547 - lr: 0.0010
# Epoch 67/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.4903 - sparse_categorical_accuracy: 0.9477 - val_loss: 0.4850 - val_sparse_categorical_accuracy: 0.9563 - lr: 0.0010
# Epoch 68/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.4782 - sparse_categorical_accuracy: 0.9523 - val_loss: 0.4853 - val_sparse_categorical_accuracy: 0.9578 - lr: 0.0010
# Epoch 69/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.4711 - sparse_categorical_accuracy: 0.9574 - val_loss: 0.4762 - val_sparse_categorical_accuracy: 0.9656 - lr: 0.0010
# Epoch 70/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.4698 - sparse_categorical_accuracy: 0.9516 - val_loss: 0.4698 - val_sparse_categorical_accuracy: 0.9453 - lr: 0.0010
# Epoch 71/150
# 80/80 [==============================] - 4s 44ms/step - loss: 0.4633 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.4817 - val_sparse_categorical_accuracy: 0.9141 - lr: 0.0010
# Epoch 72/150
# 80/80 [==============================] - 3s 40ms/step - loss: 0.4549 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.4613 - val_sparse_categorical_accuracy: 0.9453 - lr: 0.0010
# Epoch 73/150
# 80/80 [==============================] - 3s 41ms/step - loss: 0.4513 - sparse_categorical_accuracy: 0.9555 - val_loss: 0.4585 - val_sparse_categorical_accuracy: 0.9641 - lr: 0.0010
# Epoch 74/150
# 80/80 [==============================] - 4s 50ms/step - loss: 0.4375 - sparse_categorical_accuracy: 0.9641 - val_loss: 0.4515 - val_sparse_categorical_accuracy: 0.9594 - lr: 0.0010
# Epoch 75/150
# 80/80 [==============================] - 4s 51ms/step - loss: 0.4355 - sparse_categorical_accuracy: 0.9570 - val_loss: 0.4410 - val_sparse_categorical_accuracy: 0.9578 - lr: 0.0010
# Epoch 76/150
# 80/80 [==============================] - 3s 41ms/step - loss: 0.4314 - sparse_categorical_accuracy: 0.9605 - val_loss: 0.4383 - val_sparse_categorical_accuracy: 0.9609 - lr: 0.0010
# Epoch 77/150
# 80/80 [==============================] - 4s 44ms/step - loss: 0.4273 - sparse_categorical_accuracy: 0.9559 - val_loss: 0.4297 - val_sparse_categorical_accuracy: 0.9672 - lr: 0.0010
# Epoch 78/150
# 80/80 [==============================] - 4s 44ms/step - loss: 0.4181 - sparse_categorical_accuracy: 0.9629 - val_loss: 0.4245 - val_sparse_categorical_accuracy: 0.9656 - lr: 0.0010
# Epoch 79/150
# 80/80 [==============================] - 3s 40ms/step - loss: 0.4109 - sparse_categorical_accuracy: 0.9621 - val_loss: 0.4204 - val_sparse_categorical_accuracy: 0.9359 - lr: 0.0010
# Epoch 80/150
# 80/80 [==============================] - 3s 41ms/step - loss: 0.4101 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.4128 - val_sparse_categorical_accuracy: 0.9578 - lr: 0.0010
# Epoch 81/150
# 80/80 [==============================] - 4s 47ms/step - loss: 0.4008 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.4081 - val_sparse_categorical_accuracy: 0.9609 - lr: 0.0010
# Epoch 82/150
# 80/80 [==============================] - 4s 45ms/step - loss: 0.4045 - sparse_categorical_accuracy: 0.9598 - val_loss: 0.4137 - val_sparse_categorical_accuracy: 0.9641 - lr: 0.0010
# Epoch 83/150
# 80/80 [==============================] - 4s 45ms/step - loss: 0.3956 - sparse_categorical_accuracy: 0.9613 - val_loss: 0.4074 - val_sparse_categorical_accuracy: 0.9641 - lr: 0.0010
# Epoch 84/150
# 80/80 [==============================] - 4s 46ms/step - loss: 0.3884 - sparse_categorical_accuracy: 0.9641 - val_loss: 0.3975 - val_sparse_categorical_accuracy: 0.9672 - lr: 0.0010
# Epoch 85/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.3880 - sparse_categorical_accuracy: 0.9668 - val_loss: 0.3907 - val_sparse_categorical_accuracy: 0.9641 - lr: 0.0010
# Epoch 86/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.3870 - sparse_categorical_accuracy: 0.9629 - val_loss: 0.3814 - val_sparse_categorical_accuracy: 0.9578 - lr: 0.0010
# Epoch 87/150
# 80/80 [==============================] - 4s 48ms/step - loss: 0.3758 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.3825 - val_sparse_categorical_accuracy: 0.9719 - lr: 0.0010
# Epoch 88/150
# 80/80 [==============================] - 4s 45ms/step - loss: 0.3720 - sparse_categorical_accuracy: 0.9680 - val_loss: 0.3787 - val_sparse_categorical_accuracy: 0.9609 - lr: 0.0010
# Epoch 89/150
# 80/80 [==============================] - 3s 32ms/step - loss: 0.3611 - sparse_categorical_accuracy: 0.9695 - val_loss: 0.3773 - val_sparse_categorical_accuracy: 0.9672 - lr: 0.0010
# Epoch 90/150
# 80/80 [==============================] - 3s 38ms/step - loss: 0.3689 - sparse_categorical_accuracy: 0.9625 - val_loss: 0.3875 - val_sparse_categorical_accuracy: 0.9547 - lr: 0.0010
# Epoch 91/150
# 80/80 [==============================] - 3s 35ms/step - loss: 0.3536 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.3715 - val_sparse_categorical_accuracy: 0.9594 - lr: 0.0010
# Epoch 92/150
# 80/80 [==============================] - 3s 34ms/step - loss: 0.3554 - sparse_categorical_accuracy: 0.9648 - val_loss: 0.3564 - val_sparse_categorical_accuracy: 0.9594 - lr: 0.0010
# Epoch 93/150
# 80/80 [==============================] - 3s 38ms/step - loss: 0.3574 - sparse_categorical_accuracy: 0.9672 - val_loss: 0.3500 - val_sparse_categorical_accuracy: 0.9594 - lr: 0.0010
# Epoch 94/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.3388 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.3525 - val_sparse_categorical_accuracy: 0.9688 - lr: 0.0010
# Epoch 95/150
# 80/80 [==============================] - 4s 47ms/step - loss: 0.3397 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.3445 - val_sparse_categorical_accuracy: 0.9641 - lr: 0.0010
# Epoch 96/150
# 80/80 [==============================] - 4s 44ms/step - loss: 0.3362 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.3575 - val_sparse_categorical_accuracy: 0.9563 - lr: 0.0010
# Epoch 97/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.3336 - sparse_categorical_accuracy: 0.9668 - val_loss: 0.3408 - val_sparse_categorical_accuracy: 0.9688 - lr: 0.0010
# Epoch 98/150
# 80/80 [==============================] - 3s 41ms/step - loss: 0.3296 - sparse_categorical_accuracy: 0.9656 - val_loss: 0.3419 - val_sparse_categorical_accuracy: 0.9672 - lr: 0.0010
# Epoch 99/150
# 80/80 [==============================] - 4s 54ms/step - loss: 0.3196 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.3268 - val_sparse_categorical_accuracy: 0.9703 - lr: 0.0010
# Epoch 100/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.3207 - sparse_categorical_accuracy: 0.9688 - val_loss: 0.3257 - val_sparse_categorical_accuracy: 0.9594 - lr: 0.0010
# Epoch 101/150
# 80/80 [==============================] - 3s 40ms/step - loss: 0.3153 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.3268 - val_sparse_categorical_accuracy: 0.9703 - lr: 0.0010
# Epoch 102/150
# 80/80 [==============================] - 4s 45ms/step - loss: 0.3156 - sparse_categorical_accuracy: 0.9734 - val_loss: 0.3345 - val_sparse_categorical_accuracy: 0.9641 - lr: 0.0010
# Epoch 103/150
# 80/80 [==============================] - 4s 44ms/step - loss: 0.3140 - sparse_categorical_accuracy: 0.9730 - val_loss: 0.3207 - val_sparse_categorical_accuracy: 0.9516 - lr: 0.0010
# Epoch 104/150
# 80/80 [==============================] - 3s 40ms/step - loss: 0.3051 - sparse_categorical_accuracy: 0.9672 - val_loss: 0.3130 - val_sparse_categorical_accuracy: 0.9688 - lr: 0.0010
# Epoch 105/150
# 80/80 [==============================] - 4s 44ms/step - loss: 0.2991 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.3064 - val_sparse_categorical_accuracy: 0.9656 - lr: 0.0010
# Epoch 106/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.2970 - sparse_categorical_accuracy: 0.9723 - val_loss: 0.3063 - val_sparse_categorical_accuracy: 0.9609 - lr: 0.0010
# Epoch 107/150
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2948 - sparse_categorical_accuracy: 0.9711 - val_loss: 0.3074 - val_sparse_categorical_accuracy: 0.9594 - lr: 0.0010
# Epoch 108/150
# 80/80 [==============================] - 4s 46ms/step - loss: 0.2968 - sparse_categorical_accuracy: 0.9680 - val_loss: 0.2983 - val_sparse_categorical_accuracy: 0.9641 - lr: 0.0010
# Epoch 109/150
# 80/80 [==============================] - 4s 52ms/step - loss: 0.2859 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.3170 - val_sparse_categorical_accuracy: 0.9656 - lr: 0.0010
# Epoch 110/150
# 80/80 [==============================] - 4s 52ms/step - loss: 0.2903 - sparse_categorical_accuracy: 0.9707 - val_loss: 0.2946 - val_sparse_categorical_accuracy: 0.9609 - lr: 0.0010
# Epoch 111/150
# 80/80 [==============================] - 4s 46ms/step - loss: 0.2839 - sparse_categorical_accuracy: 0.9742 - val_loss: 0.2894 - val_sparse_categorical_accuracy: 0.9594 - lr: 0.0010
# Epoch 112/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.2821 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.2883 - val_sparse_categorical_accuracy: 0.9672 - lr: 0.0010
# Epoch 113/150
# 80/80 [==============================] - 4s 46ms/step - loss: 0.2763 - sparse_categorical_accuracy: 0.9727 - val_loss: 0.2889 - val_sparse_categorical_accuracy: 0.9609 - lr: 0.0010
# Epoch 114/150
# 80/80 [==============================] - 3s 38ms/step - loss: 0.2744 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.2997 - val_sparse_categorical_accuracy: 0.9656 - lr: 0.0010
# Epoch 115/150
# 80/80 [==============================] - 4s 49ms/step - loss: 0.2699 - sparse_categorical_accuracy: 0.9707 - val_loss: 0.2753 - val_sparse_categorical_accuracy: 0.9688 - lr: 0.0010
# Epoch 116/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.2674 - sparse_categorical_accuracy: 0.9746 - val_loss: 0.2779 - val_sparse_categorical_accuracy: 0.9688 - lr: 0.0010
# Epoch 117/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.2705 - sparse_categorical_accuracy: 0.9723 - val_loss: 0.2747 - val_sparse_categorical_accuracy: 0.9688 - lr: 0.0010
# Epoch 118/150
# 80/80 [==============================] - 4s 46ms/step - loss: 0.2708 - sparse_categorical_accuracy: 0.9688 - val_loss: 0.2712 - val_sparse_categorical_accuracy: 0.9625 - lr: 0.0010
# Epoch 119/150
# 80/80 [==============================] - 6s 78ms/step - loss: 0.2541 - sparse_categorical_accuracy: 0.9734 - val_loss: 0.2808 - val_sparse_categorical_accuracy: 0.9547 - lr: 0.0010
# Epoch 120/150
# 80/80 [==============================] - 4s 50ms/step - loss: 0.2576 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.2692 - val_sparse_categorical_accuracy: 0.9641 - lr: 0.0010
# Epoch 121/150
# 80/80 [==============================] - 4s 46ms/step - loss: 0.2614 - sparse_categorical_accuracy: 0.9711 - val_loss: 0.2617 - val_sparse_categorical_accuracy: 0.9656 - lr: 0.0010
# Epoch 122/150
# 80/80 [==============================] - 4s 49ms/step - loss: 0.2501 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.2581 - val_sparse_categorical_accuracy: 0.9719 - lr: 0.0010
# Epoch 123/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.2508 - sparse_categorical_accuracy: 0.9734 - val_loss: 0.2584 - val_sparse_categorical_accuracy: 0.9688 - lr: 0.0010
# Epoch 124/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.2425 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.2518 - val_sparse_categorical_accuracy: 0.9688 - lr: 0.0010
# Epoch 125/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.2445 - sparse_categorical_accuracy: 0.9742 - val_loss: 0.2761 - val_sparse_categorical_accuracy: 0.9563 - lr: 0.0010
# Epoch 126/150
# 80/80 [==============================] - 3s 39ms/step - loss: 0.2409 - sparse_categorical_accuracy: 0.9730 - val_loss: 0.2480 - val_sparse_categorical_accuracy: 0.9719 - lr: 0.0010
# Epoch 127/150
# 80/80 [==============================] - 4s 54ms/step - loss: 0.2414 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.2510 - val_sparse_categorical_accuracy: 0.9719 - lr: 0.0010
# Epoch 128/150
# 80/80 [==============================] - 4s 47ms/step - loss: 0.2365 - sparse_categorical_accuracy: 0.9730 - val_loss: 0.2679 - val_sparse_categorical_accuracy: 0.9641 - lr: 0.0010
# Epoch 129/150
# 80/80 [==============================] - 4s 48ms/step - loss: 0.2344 - sparse_categorical_accuracy: 0.9746 - val_loss: 0.2428 - val_sparse_categorical_accuracy: 0.9703 - lr: 0.0010
# Epoch 130/150
# 80/80 [==============================] - 4s 46ms/step - loss: 0.2353 - sparse_categorical_accuracy: 0.9746 - val_loss: 0.2441 - val_sparse_categorical_accuracy: 0.9578 - lr: 0.0010
# Epoch 131/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.2360 - sparse_categorical_accuracy: 0.9723 - val_loss: 0.2470 - val_sparse_categorical_accuracy: 0.9578 - lr: 0.0010
# Epoch 132/150
# 80/80 [==============================] - 4s 44ms/step - loss: 0.2272 - sparse_categorical_accuracy: 0.9723 - val_loss: 0.2626 - val_sparse_categorical_accuracy: 0.9516 - lr: 0.0010
# Epoch 133/150
# 80/80 [==============================] - 4s 46ms/step - loss: 0.2206 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.2444 - val_sparse_categorical_accuracy: 0.9609 - lr: 0.0010
# Epoch 134/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.2256 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.2319 - val_sparse_categorical_accuracy: 0.9688 - lr: 0.0010
# Epoch 135/150
# 80/80 [==============================] - 4s 45ms/step - loss: 0.2290 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.2416 - val_sparse_categorical_accuracy: 0.9688 - lr: 0.0010
# Epoch 136/150
# 80/80 [==============================] - 3s 44ms/step - loss: 0.2282 - sparse_categorical_accuracy: 0.9699 - val_loss: 0.2337 - val_sparse_categorical_accuracy: 0.9641 - lr: 0.0010
# Epoch 137/150
# 80/80 [==============================] - 3s 42ms/step - loss: 0.2147 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.2431 - val_sparse_categorical_accuracy: 0.9688 - lr: 0.0010
# Epoch 138/150
# 80/80 [==============================] - 4s 46ms/step - loss: 0.2168 - sparse_categorical_accuracy: 0.9730 - val_loss: 0.2223 - val_sparse_categorical_accuracy: 0.9703 - lr: 0.0010
# Epoch 139/150
# 80/80 [==============================] - 4s 46ms/step - loss: 0.2272 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.2204 - val_sparse_categorical_accuracy: 0.9734 - lr: 0.0010
# Epoch 140/150
# 80/80 [==============================] - 4s 50ms/step - loss: 0.2160 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.2465 - val_sparse_categorical_accuracy: 0.9609 - lr: 0.0010
# Epoch 141/150
# 80/80 [==============================] - 3s 41ms/step - loss: 0.2089 - sparse_categorical_accuracy: 0.9723 - val_loss: 0.2872 - val_sparse_categorical_accuracy: 0.9359 - lr: 0.0010
# Epoch 142/150
# 80/80 [==============================] - 4s 44ms/step - loss: 0.2095 - sparse_categorical_accuracy: 0.9762 - val_loss: 0.2248 - val_sparse_categorical_accuracy: 0.9688 - lr: 0.0010
# Epoch 143/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.2103 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.2162 - val_sparse_categorical_accuracy: 0.9688 - lr: 0.0010
# Epoch 144/150
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2078 - sparse_categorical_accuracy: 0.9723 - val_loss: 0.2110 - val_sparse_categorical_accuracy: 0.9703 - lr: 0.0010
# Epoch 145/150
# 80/80 [==============================] - 3s 43ms/step - loss: 0.1979 - sparse_categorical_accuracy: 0.9727 - val_loss: 0.2174 - val_sparse_categorical_accuracy: 0.9688 - lr: 0.0010
# Epoch 146/150
# 80/80 [==============================] - 4s 50ms/step - loss: 0.1998 - sparse_categorical_accuracy: 0.9746 - val_loss: 0.2221 - val_sparse_categorical_accuracy: 0.9641 - lr: 0.0010
# Epoch 147/150
# 80/80 [==============================] - 4s 48ms/step - loss: 0.2006 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.2284 - val_sparse_categorical_accuracy: 0.9578 - lr: 0.0010
# Epoch 148/150
# 80/80 [==============================] - 4s 45ms/step - loss: 0.2014 - sparse_categorical_accuracy: 0.9727 - val_loss: 0.2078 - val_sparse_categorical_accuracy: 0.9719 - lr: 0.0010
# Epoch 149/150
# 80/80 [==============================] - 5s 63ms/step - loss: 0.1985 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.2090 - val_sparse_categorical_accuracy: 0.9703 - lr: 0.0010
# Epoch 150/150
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1940 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.2074 - val_sparse_categorical_accuracy: 0.9734 - lr: 0.0010

# %%
# model = keras.saving.load_model("best_model.keras")

# test_loss, test_acc = model.evaluate(x_test, y_test)

# print("Test accuracy", test_acc)
# print("Test loss", test_loss)

# %%
from keras.models import load_model

# Load the model
model = load_model("best_model.keras")

# Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
# Out:
# 25/25 [==============================] - 1s 5ms/step - loss: 0.1859 - sparse_categorical_accuracy: 0.9837
# Test accuracy: 0.9837499856948853
# Test loss: 0.1859169900417328

# %%
# model info
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 1)]          0
#
#  conv1d (Conv1D)             (None, 128, 4)            16
#
#  batch_normalization (BatchN  (None, 128, 4)           16
#  ormalization)
#
#  re_lu (ReLU)                (None, 128, 4)            0
#
#  global_average_pooling1d (G  (None, 4)                0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 4)                 20
#
# =================================================================
# Total params: 52
# Trainable params: 44
# Non-trainable params: 8
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt

# Set font to Times New Roman
plt.rcParams["font.family"] = "Times New Roman"

# Plot training history
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel("accuracy", fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")

# Set x-axis limits
plt.xlim(-20, 160)

# Save the figure
plt.savefig("CNN_Classifier.png")

# Show the plot
plt.show()
plt.close()

# %%
# save model
model.save("cnn_model.keras")

# %%
# save x_test, y_test as npy file, this partition is consistent with the partition in the previous step

# x_test save
np.save('x_test.npy', x_test)

print(x_test.shape)

# y_test save, 1-hot encoding first
tmp_y_test = np.zeros((y_test.shape[0], num_classes))
for i in range(y_test.shape[0]):
    tmp_y_test[i][y_test[i][0]] = 1

np.save('y_test.npy', tmp_y_test)

print(tmp_y_test.shape)
# Out:
# (800, 128, 1)
# (800, 4)
