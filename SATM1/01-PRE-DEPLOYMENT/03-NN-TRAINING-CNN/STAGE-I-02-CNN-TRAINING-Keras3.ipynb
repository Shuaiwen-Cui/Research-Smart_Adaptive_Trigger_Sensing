# %% [markdown]
# # CNN FOR EVENT CLASSIFICATION

# %% [markdown]
# ## DATA GENERATION

# %%
# DEPENDENCIES

import numpy as np
import sys
import os
import matplotlib.pyplot as plt
import random
import time
import datetime
import pandas as pd

import prenn # for deep learning

# %%
# RAW DATA
AVPath = '../DATA/SYN_RES/RESPONSE_AV.npy'
EQPath = '../DATA/SYN_RES/RESPONSE_EQ.npy'
IPPath = '../DATA/SYN_RES/RESPONSE_IP.npy'
SWPath = '../DATA/SYN_RES/RESPONSE_SW.npy'

# Load Data + add noise to the data
RESPONSE_AV = np.load(AVPath)
RESPONSE_EQ = np.load(EQPath)
RESPONSE_IP = np.load(IPPath)
RESPONSE_SW = np.load(SWPath)

## only use part of the data
raw_len = RESPONSE_AV.shape[0]
ratio = 1.0 # ALL DATA USED FOR TRAINING
use_len = int(raw_len * ratio)

RESPONSE_AV = RESPONSE_AV[:use_len]
RESPONSE_EQ = RESPONSE_EQ[:use_len]
RESPONSE_IP = RESPONSE_IP[:use_len]
RESPONSE_SW = RESPONSE_SW[:use_len]

## Check Data Info
print(type(RESPONSE_AV))
print('RESPONSE_AV Shape:', RESPONSE_AV.shape)
print(type(RESPONSE_EQ))
print('RESPONSE_EQ Shape:', RESPONSE_EQ.shape)
print(type(RESPONSE_IP))
print('RESPONSE_IP Shape:', RESPONSE_IP.shape)
print(type(RESPONSE_SW))
print('RESPONSE_SW Shape:', RESPONSE_SW.shape)
# Out:
# <class 'numpy.ndarray'>
# RESPONSE_AV Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_EQ Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_IP Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_SW Shape: (1000, 6000)

# %%
## Check Random Data
selected_idx = np.random.randint(RESPONSE_AV.shape[0])

## Plot Random Data - use subplot
plt.figure(figsize=(30, 10))
plt.subplot(2, 2, 1)
plt.plot(RESPONSE_AV[selected_idx, :])
plt.title('AV')
plt.subplot(2, 2, 2)
plt.plot(RESPONSE_EQ[selected_idx, :])
plt.title('EQ')
plt.subplot(2, 2, 3)
plt.plot(RESPONSE_IP[selected_idx, :])
plt.title('IP')
plt.subplot(2, 2, 4)
plt.plot(RESPONSE_SW[selected_idx, :])
plt.title('SW')
plt.show()

# %%
num_type = 4

reshape_shape_0 = RESPONSE_AV.shape[0]
reshape_shape_1 = RESPONSE_AV.shape[1]

LenTS = reshape_shape_1

# %%
# Integrate All Data into a 2D Array

## Reshape Data
RESPONSE_AV_RESHAPED = RESPONSE_AV.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_EQ_RESHAPED = RESPONSE_EQ.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_IP_RESHAPED = RESPONSE_IP.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_SW_RESHAPED = RESPONSE_SW.reshape(reshape_shape_0, reshape_shape_1)

## Stack Data
RESPONSE = np.vstack((RESPONSE_AV_RESHAPED, RESPONSE_EQ_RESHAPED, RESPONSE_IP_RESHAPED, RESPONSE_SW_RESHAPED))

## Total Number of Samples
NumSample = RESPONSE.shape[0]
print('Total Number of Samples:', NumSample)
# Out:
# Total Number of Samples: 4000

# %%
# Real Ground Truth

## Binary Form, Interest or Not
Real_GT_B = np.zeros((RESPONSE.shape[0], 1))

## Real_GT_B, only the first quarter of the data is considered as not interesting
for i in range(RESPONSE_AV.shape[0], RESPONSE.shape[0]):
    Real_GT_B[i] = 1

## plot the binary form
plt.figure()
plt.plot(Real_GT_B)
plt.show()

## Multi-Class Form, Event Type
Real_GT_M = np.zeros((RESPONSE.shape[0], 4))

## Real_GT_M, 4 types of events
for i in range(num_type):
    Real_GT_M[i*reshape_shape_0:(i+1)*reshape_shape_0, i] = 1

## plot the multi-class form, 4 subplots, each subplot for one type of event
plt.figure(figsize=(30, 10))
plt.subplot(4, 1, 1)
plt.plot(Real_GT_M[:, 0])
plt.title('AV')
plt.subplot(4, 1, 2)
plt.plot(Real_GT_M[:, 1])
plt.title('EQ')
plt.subplot(4, 1, 3)
plt.plot(Real_GT_M[:, 2])
plt.title('IP')
plt.subplot(4, 1, 4)
plt.plot(Real_GT_M[:, 3])
plt.title('SW')
plt.show()

# %%
# process parameters

# nn input length
nn_in_len = 128

# time step
dt = 0.01

# nperseg
nperseg = 128

# output length

# %%
NN_IN_DATA = np.zeros((NumSample, nn_in_len))

for i in range(NumSample):
    NN_IN_DATA[i, :] = prenn.prenn(RESPONSE[i, :].reshape(1, -1), dt, nperseg, nn_in_len)

# %%
# check whether nan exists
nan_idx = np.argwhere(np.isnan(NN_IN_DATA))
print(nan_idx)
# Out:
# [[2048    0]
#  [2048    1]
#  [2048    2]
#  [2048    3]
#  [2048    4]
#  [2048    5]
#  [2048    6]
#  [2048    7]
#  [2048    8]
#  [2048    9]
#  [2048   10]
#  [2048   11]
#  [2048   12]
#  [2048   13]
#  [2048   14]
#  [2048   15]
#  [2048   16]
#  [2048   17]
#  [2048   18]
#  [2048   19]
#  [2048   20]
#  [2048   21]
#  [2048   22]
#  [2048   23]
#  [2048   24]
#  [2048   25]
#  [2048   26]
#  [2048   27]
#  [2048   28]
#  [2048   29]
#  [2048   30]
#  [2048   31]
#  [2048   32]
#  [2048   33]
#  [2048   34]
#  [2048   35]
#  [2048   36]
#  [2048   37]
#  [2048   38]
#  [2048   39]
#  [2048   40]
#  [2048   41]
#  [2048   42]
#  [2048   43]
#  [2048   44]
#  [2048   45]
#  [2048   46]
#  [2048   47]
#  [2048   48]
#  [2048   49]
#  [2048   50]
#  [2048   51]
#  [2048   52]
#  [2048   53]
#  [2048   54]
#  [2048   55]
#  [2048   56]
#  [2048   57]
#  [2048   58]
#  [2048   59]
#  [2048   60]
#  [2048   61]
#  [2048   62]
#  [2048   63]
#  [2355    0]
#  [2355    1]
#  [2355    2]
#  [2355    3]
#  [2355    4]
#  [2355    5]
#  [2355    6]
#  [2355    7]
#  [2355    8]
#  [2355    9]
#  [2355   10]
#  [2355   11]
#  [2355   12]
#  [2355   13]
#  [2355   14]
#  [2355   15]
#  [2355   16]
#  [2355   17]
#  [2355   18]
#  [2355   19]
#  [2355   20]
#  [2355   21]
#  [2355   22]
#  [2355   23]
#  [2355   24]
#  [2355   25]
#  [2355   26]
#  [2355   27]
#  [2355   28]
#  [2355   29]
#  [2355   30]
#  [2355   31]
#  [2355   32]
#  [2355   33]
#  [2355   34]
#  [2355   35]
#  [2355   36]
#  [2355   37]
#  [2355   38]
#  [2355   39]
#  [2355   40]
#  [2355   41]
#  [2355   42]
#  [2355   43]
#  [2355   44]
#  [2355   45]
#  [2355   46]
#  [2355   47]
#  [2355   48]
#  [2355   49]
#  [2355   50]
#  [2355   51]
#  [2355   52]
#  [2355   53]
#  [2355   54]
#  [2355   55]
#  [2355   56]
#  [2355   57]
#  [2355   58]
#  [2355   59]
#  [2355   60]
#  [2355   61]
#  [2355   62]
#  [2355   63]
#  [2392    0]
#  [2392    1]
#  [2392    2]
#  [2392    3]
#  [2392    4]
#  [2392    5]
#  [2392    6]
#  [2392    7]
#  [2392    8]
#  [2392    9]
#  [2392   10]
#  [2392   11]
#  [2392   12]
#  [2392   13]
#  [2392   14]
#  [2392   15]
#  [2392   16]
#  [2392   17]
#  [2392   18]
#  [2392   19]
#  [2392   20]
#  [2392   21]
#  [2392   22]
#  [2392   23]
#  [2392   24]
#  [2392   25]
#  [2392   26]
#  [2392   27]
#  [2392   28]
#  [2392   29]
#  [2392   30]
#  [2392   31]
#  [2392   32]
#  [2392   33]
#  [2392   34]
#  [2392   35]
#  [2392   36]
#  [2392   37]
#  [2392   38]
#  [2392   39]
#  [2392   40]
#  [2392   41]
#  [2392   42]
#  [2392   43]
#  [2392   44]
#  [2392   45]
#  [2392   46]
#  [2392   47]
#  [2392   48]
#  [2392   49]
#  [2392   50]
#  [2392   51]
#  [2392   52]
#  [2392   53]
#  [2392   54]
#  [2392   55]
#  [2392   56]
#  [2392   57]
#  [2392   58]
#  [2392   59]
#  [2392   60]
#  [2392   61]
#  [2392   62]
#  [2392   63]
#  [2457    0]
#  [2457    1]
#  [2457    2]
#  [2457    3]
#  [2457    4]
#  [2457    5]
#  [2457    6]
#  [2457    7]
#  [2457    8]
#  [2457    9]
#  [2457   10]
#  [2457   11]
#  [2457   12]
#  [2457   13]
#  [2457   14]
#  [2457   15]
#  [2457   16]
#  [2457   17]
#  [2457   18]
#  [2457   19]
#  [2457   20]
#  [2457   21]
#  [2457   22]
#  [2457   23]
#  [2457   24]
#  [2457   25]
#  [2457   26]
#  [2457   27]
#  [2457   28]
#  [2457   29]
#  [2457   30]
#  [2457   31]
#  [2457   32]
#  [2457   33]
#  [2457   34]
#  [2457   35]
#  [2457   36]
#  [2457   37]
#  [2457   38]
#  [2457   39]
#  [2457   40]
#  [2457   41]
#  [2457   42]
#  [2457   43]
#  [2457   44]
#  [2457   45]
#  [2457   46]
#  [2457   47]
#  [2457   48]
#  [2457   49]
#  [2457   50]
#  [2457   51]
#  [2457   52]
#  [2457   53]
#  [2457   54]
#  [2457   55]
#  [2457   56]
#  [2457   57]
#  [2457   58]
#  [2457   59]
#  [2457   60]
#  [2457   61]
#  [2457   62]
#  [2457   63]
#  [2496    0]
#  [2496    1]
#  [2496    2]
#  [2496    3]
#  [2496    4]
#  [2496    5]
#  [2496    6]
#  [2496    7]
#  [2496    8]
#  [2496    9]
#  [2496   10]
#  [2496   11]
#  [2496   12]
#  [2496   13]
#  [2496   14]
#  [2496   15]
#  [2496   16]
#  [2496   17]
#  [2496   18]
#  [2496   19]
#  [2496   20]
#  [2496   21]
#  [2496   22]
#  [2496   23]
#  [2496   24]
#  [2496   25]
#  [2496   26]
#  [2496   27]
#  [2496   28]
#  [2496   29]
#  [2496   30]
#  [2496   31]
#  [2496   32]
#  [2496   33]
#  [2496   34]
#  [2496   35]
#  [2496   36]
#  [2496   37]
#  [2496   38]
#  [2496   39]
#  [2496   40]
#  [2496   41]
#  [2496   42]
#  [2496   43]
#  [2496   44]
#  [2496   45]
#  [2496   46]
#  [2496   47]
#  [2496   48]
#  [2496   49]
#  [2496   50]
#  [2496   51]
#  [2496   52]
#  [2496   53]
#  [2496   54]
#  [2496   55]
#  [2496   56]
#  [2496   57]
#  [2496   58]
#  [2496   59]
#  [2496   60]
#  [2496   61]
#  [2496   62]
#  [2496   63]]

# %%
# plot to check
# selected_idx = np.random.randint(NumSample)
selected_idx = 599
plt.figure()
plt.plot(NN_IN_DATA[selected_idx, :])
plt.show()

# %%
# save data as npy file
np.save('NN_IN_DATA.npy', NN_IN_DATA)

# %%
# LABELS
NN_IN_LABEL = np.zeros((NumSample, 1))
NN_IN_LABEL_1HOT = np.zeros((NumSample, 4))

# %%
# NN_IN_LABEL & NN_IN_LABEL_1HOT
for i in range(NumSample):
    if i < reshape_shape_0:
        NN_IN_LABEL[i] = 0
        NN_IN_LABEL_1HOT[i, 0] = 1
    elif i < reshape_shape_0 * 2:
        NN_IN_LABEL[i] = 1
        NN_IN_LABEL_1HOT[i, 1] = 1
    elif i < reshape_shape_0 * 3:
        NN_IN_LABEL[i] = 2
        NN_IN_LABEL_1HOT[i, 2] = 1
    else:
        NN_IN_LABEL[i] = 3
        NN_IN_LABEL_1HOT[i, 3] = 1

# %%
## plot NN_IN_LABEL
plt.figure()
plt.plot(NN_IN_LABEL)
plt.show()

# %%
## plot NN_IN_LABEL_1HOT
plt.figure(figsize=(30, 10))
plt.subplot(4, 1, 1)
plt.plot(NN_IN_LABEL_1HOT[:, 0])
plt.title('AV')
plt.subplot(4, 1, 2)
plt.plot(NN_IN_LABEL_1HOT[:, 1])
plt.title('EQ')
plt.subplot(4, 1, 3)
plt.plot(NN_IN_LABEL_1HOT[:, 2])
plt.title('IP')
plt.subplot(4, 1, 4)
plt.plot(NN_IN_LABEL_1HOT[:, 3])
plt.title('SW')
plt.show()

# %%
# save data as npy file
np.save('NN_IN_LABEL.npy', NN_IN_LABEL)
np.save('NN_IN_LABEL_1HOT.npy', NN_IN_LABEL_1HOT)

# %% [markdown]
# ## CNN MODEL FOR CLASSIFICATION

# %%
# dependencies
import numpy as np
import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
import tf2onnx
import onnx
# Out:
# WARNING:tensorflow:From C:\Users\cswof\AppData\Roaming\Python\Python312\site-packages\tf2onnx\tf_loader.py:68: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\cswof\AppData\Roaming\Python\Python312\site-packages\tf2onnx\tf_loader.py:72: The name tf.train.import_meta_graph is deprecated. Please use tf.compat.v1.train.import_meta_graph instead.

# %%
# data preparation

data = np.load('NN_IN_DATA.npy')
# expand dimensions to 3D
data = np.expand_dims(data, axis=2)

print(data.shape)

label_1h = np.load('NN_IN_LABEL_1HOT.npy').astype(int)
print(label_1h.shape)

label = np.argmax(label_1h, axis=1).astype(int)
label = label.reshape((-1,1))

print(label.shape)
# Out:
# (4000, 128, 1)
# (4000, 4)
# (4000, 1)

# %%
# split data as x_train, x_test, y_train, y_test
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=42)

# check info
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3200, 128, 1)
# (800, 128, 1)
# (3200, 1)
# (800, 1)

# %%
num_classes = np.unique(label).shape[0]
print(num_classes)
# Out:
# 4

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=4, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    # conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    # conv2 = keras.layers.BatchNormalization()(conv2)
    # conv2 = keras.layers.ReLU()(conv2)

    # conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    # conv3 = keras.layers.BatchNormalization()(conv3)
    # conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv1)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
# keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 150
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan - sparse_categorical_accuracy: 0.2322 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 2/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2652 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 3/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2629 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 4/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2505 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 5/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2545 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 6/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2604 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 7/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2455 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 8/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2542 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 9/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2542 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 10/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2521 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 11/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2433 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 12/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2551 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 13/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2554 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 14/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2545 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 15/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2554 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 16/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2524 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 17/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2485 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 18/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2435 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 19/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2593 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 20/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2381 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 0.0010
# Epoch 21/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2363 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 22/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2427 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 23/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2497 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 24/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2525 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 25/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2544 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 26/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2524 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 27/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2480 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 28/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2621 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 29/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2544 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 30/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2510 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 31/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2609 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 32/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2491 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 33/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2389 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 34/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2408 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 35/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2372 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 36/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan - sparse_categorical_accuracy: 0.2508 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 37/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2547 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 38/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2563 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 39/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2515 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 40/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2609 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 5.0000e-04
# Epoch 41/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2455 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 2.5000e-04
# Epoch 42/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2495 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 2.5000e-04
# Epoch 43/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2557 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 2.5000e-04
# Epoch 44/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2366 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 2.5000e-04
# Epoch 45/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2579 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 2.5000e-04
# Epoch 46/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2546 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 2.5000e-04
# Epoch 47/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2462 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 2.5000e-04
# Epoch 48/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2591 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 2.5000e-04
# Epoch 49/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2587 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 2.5000e-04
# Epoch 50/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2414 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 2.5000e-04
# Epoch 51/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.2512 - val_loss: nan - val_sparse_categorical_accuracy: 0.2281 - learning_rate: 2.5000e-04
# Epoch 51: early stopping

# %%
# model = keras.saving.load_model("best_model.keras")

# test_loss, test_acc = model.evaluate(x_test, y_test)

# print("Test accuracy", test_acc)
# print("Test loss", test_loss)

# %%
# Load the model
model = keras.saving.load_model("best_model.keras")

# Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - sparse_categorical_accuracy: 0.9749
# Test accuracy: 0.9837499856948853
# Test loss: nan

# %%
# model info
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 128, 4)         │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 4)         │            16 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 128, 4)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 4)              │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │            20 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 142 (572.00 B)
#  Trainable params: 44 (176.00 B)
#  Non-trainable params: 8 (32.00 B)
#  Optimizer params: 90 (364.00 B)

# %%
import matplotlib.pyplot as plt

# Set font to Times New Roman
plt.rcParams["font.family"] = "Times New Roman"

# Plot training history
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel("accuracy", fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")

# Set x-axis limits
plt.xlim(-20, 160)

# Save the figure
plt.savefig("CNN_Classifier.png")

# Show the plot
plt.show()
plt.close()

# %%
# save model
model.save("cnn_model.keras")

# %%
import matplotlib.pyplot as plt

# Set font to Times New Roman
plt.rcParams["font.family"] = "Times New Roman"

# Plot training history
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("CNN Classifier Training Curve")
plt.ylabel("Accuracy", fontsize="large")
plt.xlabel("Epoch", fontsize="large")
plt.legend(["Train", "Val"], loc="best")

# Set x-axis limits
plt.xlim(-20, 160)

# Save the figure
plt.savefig("CNN_Classifier.png")

# Show the plot
plt.show()
plt.close()

# %%
# save x_test, y_test as npy file, this partition is consistent with the partition in the previous step

# x_test save
np.save('x_test.npy', x_test)

print(x_test.shape)

# y_test save, 1-hot encoding first
tmp_y_test = np.zeros((y_test.shape[0], num_classes))
for i in range(y_test.shape[0]):
    tmp_y_test[i][y_test[i][0]] = 1

np.save('y_test.npy', tmp_y_test)

print(tmp_y_test.shape)
# Out:
# (800, 128, 1)
# (800, 4)
