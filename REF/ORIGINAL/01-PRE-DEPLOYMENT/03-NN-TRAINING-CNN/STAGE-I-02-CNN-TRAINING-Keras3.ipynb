# %% [markdown]
# # CNN FOR EVENT CLASSIFICATION

# %% [markdown]
# ## DATA GENERATION

# %%
# DEPENDENCIES

import numpy as np
import sys
import os
import matplotlib.pyplot as plt
import random
import time
import datetime
import pandas as pd

import prenn # for deep learning

# %%
# RAW DATA
AVPath = '../DATA/SYN_RES/RESPONSE_AV.npy'
EQPath = '../DATA/SYN_RES/RESPONSE_EQ.npy'
IPPath = '../DATA/SYN_RES/RESPONSE_IP.npy'
SWPath = '../DATA/SYN_RES/RESPONSE_SW.npy'

# Load Data + add noise to the data
RESPONSE_AV = np.load(AVPath)
RESPONSE_EQ = np.load(EQPath)
RESPONSE_IP = np.load(IPPath)
RESPONSE_SW = np.load(SWPath)

## only use part of the data
raw_len = RESPONSE_AV.shape[0]
ratio = 1.0 # ALL DATA USED FOR TRAINING
use_len = int(raw_len * ratio)

RESPONSE_AV = RESPONSE_AV[:use_len]
RESPONSE_EQ = RESPONSE_EQ[:use_len]
RESPONSE_IP = RESPONSE_IP[:use_len]
RESPONSE_SW = RESPONSE_SW[:use_len]

## Check Data Info
print(type(RESPONSE_AV))
print('RESPONSE_AV Shape:', RESPONSE_AV.shape)
print(type(RESPONSE_EQ))
print('RESPONSE_EQ Shape:', RESPONSE_EQ.shape)
print(type(RESPONSE_IP))
print('RESPONSE_IP Shape:', RESPONSE_IP.shape)
print(type(RESPONSE_SW))
print('RESPONSE_SW Shape:', RESPONSE_SW.shape)
# Out:
# <class 'numpy.ndarray'>
# RESPONSE_AV Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_EQ Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_IP Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_SW Shape: (1000, 6000)

# %%
## Check Random Data
selected_idx = np.random.randint(RESPONSE_AV.shape[0])

## Plot Random Data - use subplot
plt.figure(figsize=(30, 10))
plt.subplot(2, 2, 1)
plt.plot(RESPONSE_AV[selected_idx, :])
plt.title('AV')
plt.subplot(2, 2, 2)
plt.plot(RESPONSE_EQ[selected_idx, :])
plt.title('EQ')
plt.subplot(2, 2, 3)
plt.plot(RESPONSE_IP[selected_idx, :])
plt.title('IP')
plt.subplot(2, 2, 4)
plt.plot(RESPONSE_SW[selected_idx, :])
plt.title('SW')
plt.show()

# %%
num_type = 4

reshape_shape_0 = RESPONSE_AV.shape[0]
reshape_shape_1 = RESPONSE_AV.shape[1]

LenTS = reshape_shape_1

# %%
# Integrate All Data into a 2D Array

## Reshape Data
RESPONSE_AV_RESHAPED = RESPONSE_AV.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_EQ_RESHAPED = RESPONSE_EQ.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_IP_RESHAPED = RESPONSE_IP.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_SW_RESHAPED = RESPONSE_SW.reshape(reshape_shape_0, reshape_shape_1)

## Stack Data
RESPONSE = np.vstack((RESPONSE_AV_RESHAPED, RESPONSE_EQ_RESHAPED, RESPONSE_IP_RESHAPED, RESPONSE_SW_RESHAPED))

## Total Number of Samples
NumSample = RESPONSE.shape[0]
print('Total Number of Samples:', NumSample)
# Out:
# Total Number of Samples: 4000

# %%
# Real Ground Truth

## Binary Form, Interest or Not
Real_GT_B = np.zeros((RESPONSE.shape[0], 1))

## Real_GT_B, only the first quarter of the data is considered as not interesting
for i in range(RESPONSE_AV.shape[0], RESPONSE.shape[0]):
    Real_GT_B[i] = 1

## plot the binary form
plt.figure()
plt.plot(Real_GT_B)
plt.show()

## Multi-Class Form, Event Type
Real_GT_M = np.zeros((RESPONSE.shape[0], 4))

## Real_GT_M, 4 types of events
for i in range(num_type):
    Real_GT_M[i*reshape_shape_0:(i+1)*reshape_shape_0, i] = 1

## plot the multi-class form, 4 subplots, each subplot for one type of event
plt.figure(figsize=(30, 10))
plt.subplot(4, 1, 1)
plt.plot(Real_GT_M[:, 0])
plt.title('AV')
plt.subplot(4, 1, 2)
plt.plot(Real_GT_M[:, 1])
plt.title('EQ')
plt.subplot(4, 1, 3)
plt.plot(Real_GT_M[:, 2])
plt.title('IP')
plt.subplot(4, 1, 4)
plt.plot(Real_GT_M[:, 3])
plt.title('SW')
plt.show()

# %%
# process parameters

# nn input length
nn_in_len = 128

# time step
dt = 0.01

# nperseg
nperseg = 128

# output length

# %%
NN_IN_DATA = np.zeros((NumSample, nn_in_len))

for i in range(NumSample):
    NN_IN_DATA[i, :] = prenn.prenn(RESPONSE[i, :].reshape(1, -1), dt, nperseg, nn_in_len)

# %%
# check whether nan exists
nan_idx = np.argwhere(np.isnan(NN_IN_DATA))
print(nan_idx)
# Out:
# []

# %%
# plot to check
# selected_idx = np.random.randint(NumSample)
selected_idx = 599
plt.figure()
plt.plot(NN_IN_DATA[selected_idx, :])
plt.show()

# %%
# save data as npy file
np.save('NN_IN_DATA.npy', NN_IN_DATA)

# %%
# LABELS
NN_IN_LABEL = np.zeros((NumSample, 1))
NN_IN_LABEL_1HOT = np.zeros((NumSample, 4))

# %%
# NN_IN_LABEL & NN_IN_LABEL_1HOT
for i in range(NumSample):
    if i < reshape_shape_0:
        NN_IN_LABEL[i] = 0
        NN_IN_LABEL_1HOT[i, 0] = 1
    elif i < reshape_shape_0 * 2:
        NN_IN_LABEL[i] = 1
        NN_IN_LABEL_1HOT[i, 1] = 1
    elif i < reshape_shape_0 * 3:
        NN_IN_LABEL[i] = 2
        NN_IN_LABEL_1HOT[i, 2] = 1
    else:
        NN_IN_LABEL[i] = 3
        NN_IN_LABEL_1HOT[i, 3] = 1

# %%
## plot NN_IN_LABEL
plt.figure()
plt.plot(NN_IN_LABEL)
plt.show()

# %%
## plot NN_IN_LABEL_1HOT
plt.figure(figsize=(30, 10))
plt.subplot(4, 1, 1)
plt.plot(NN_IN_LABEL_1HOT[:, 0])
plt.title('AV')
plt.subplot(4, 1, 2)
plt.plot(NN_IN_LABEL_1HOT[:, 1])
plt.title('EQ')
plt.subplot(4, 1, 3)
plt.plot(NN_IN_LABEL_1HOT[:, 2])
plt.title('IP')
plt.subplot(4, 1, 4)
plt.plot(NN_IN_LABEL_1HOT[:, 3])
plt.title('SW')
plt.show()

# %%
# save data as npy file
np.save('NN_IN_LABEL.npy', NN_IN_LABEL)
np.save('NN_IN_LABEL_1HOT.npy', NN_IN_LABEL_1HOT)

# %% [markdown]
# ## CNN MODEL FOR CLASSIFICATION

# %%
# dependencies
import numpy as np
import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
import tf2onnx
import onnx
# Out:
# WARNING:tensorflow:From C:\Users\cswof\AppData\Roaming\Python\Python312\site-packages\tf2onnx\tf_loader.py:68: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\cswof\AppData\Roaming\Python\Python312\site-packages\tf2onnx\tf_loader.py:72: The name tf.train.import_meta_graph is deprecated. Please use tf.compat.v1.train.import_meta_graph instead.

# %%
# data preparation

data = np.load('NN_IN_DATA.npy')
# expand dimensions to 3D
data = np.expand_dims(data, axis=2)

print(data.shape)

label_1h = np.load('NN_IN_LABEL_1HOT.npy').astype(int)
print(label_1h.shape)

label = np.argmax(label_1h, axis=1).astype(int)
label = label.reshape((-1,1))

print(label.shape)
# Out:
# (4000, 128, 1)
# (4000, 4)
# (4000, 1)

# %%
# split data as x_train, x_test, y_train, y_test
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=42)

# check info
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3200, 128, 1)
# (800, 128, 1)
# (3200, 1)
# (800, 1)

# %%
num_classes = np.unique(label).shape[0]
print(num_classes)
# Out:
# 4

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=4, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    # conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    # conv2 = keras.layers.BatchNormalization()(conv2)
    # conv2 = keras.layers.ReLU()(conv2)

    # conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    # conv3 = keras.layers.BatchNormalization()(conv3)
    # conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv1)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
# keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 150
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.4763 - sparse_categorical_accuracy: 0.2497 - val_loss: 1.3967 - val_sparse_categorical_accuracy: 0.2547 - learning_rate: 0.0010
# Epoch 2/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3897 - sparse_categorical_accuracy: 0.2520 - val_loss: 1.3706 - val_sparse_categorical_accuracy: 0.2641 - learning_rate: 0.0010
# Epoch 3/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3605 - sparse_categorical_accuracy: 0.2477 - val_loss: 1.3480 - val_sparse_categorical_accuracy: 0.2922 - learning_rate: 0.0010
# Epoch 4/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3368 - sparse_categorical_accuracy: 0.3720 - val_loss: 1.3276 - val_sparse_categorical_accuracy: 0.4766 - learning_rate: 0.0010
# Epoch 5/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3144 - sparse_categorical_accuracy: 0.4917 - val_loss: 1.3089 - val_sparse_categorical_accuracy: 0.4828 - learning_rate: 0.0010
# Epoch 6/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2980 - sparse_categorical_accuracy: 0.4909 - val_loss: 1.2888 - val_sparse_categorical_accuracy: 0.4828 - learning_rate: 0.0010
# Epoch 7/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2776 - sparse_categorical_accuracy: 0.4970 - val_loss: 1.2685 - val_sparse_categorical_accuracy: 0.4812 - learning_rate: 0.0010
# Epoch 8/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2572 - sparse_categorical_accuracy: 0.5167 - val_loss: 1.2476 - val_sparse_categorical_accuracy: 0.5906 - learning_rate: 0.0010
# Epoch 9/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2378 - sparse_categorical_accuracy: 0.4511 - val_loss: 1.2248 - val_sparse_categorical_accuracy: 0.5031 - learning_rate: 0.0010
# Epoch 10/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2134 - sparse_categorical_accuracy: 0.5678 - val_loss: 1.1993 - val_sparse_categorical_accuracy: 0.5938 - learning_rate: 0.0010
# Epoch 11/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1886 - sparse_categorical_accuracy: 0.5683 - val_loss: 1.1737 - val_sparse_categorical_accuracy: 0.5969 - learning_rate: 0.0010
# Epoch 12/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1567 - sparse_categorical_accuracy: 0.6162 - val_loss: 1.1463 - val_sparse_categorical_accuracy: 0.7125 - learning_rate: 0.0010
# Epoch 13/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1325 - sparse_categorical_accuracy: 0.7377 - val_loss: 1.1188 - val_sparse_categorical_accuracy: 0.7359 - learning_rate: 0.0010
# Epoch 14/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1100 - sparse_categorical_accuracy: 0.7284 - val_loss: 1.0917 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 15/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0893 - sparse_categorical_accuracy: 0.7451 - val_loss: 1.0657 - val_sparse_categorical_accuracy: 0.8500 - learning_rate: 0.0010
# Epoch 16/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0550 - sparse_categorical_accuracy: 0.8000 - val_loss: 1.0389 - val_sparse_categorical_accuracy: 0.8953 - learning_rate: 0.0010
# Epoch 17/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0359 - sparse_categorical_accuracy: 0.8163 - val_loss: 1.0129 - val_sparse_categorical_accuracy: 0.8687 - learning_rate: 0.0010
# Epoch 18/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9968 - sparse_categorical_accuracy: 0.8417 - val_loss: 0.9861 - val_sparse_categorical_accuracy: 0.7484 - learning_rate: 0.0010
# Epoch 19/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9764 - sparse_categorical_accuracy: 0.8949 - val_loss: 0.9643 - val_sparse_categorical_accuracy: 0.7172 - learning_rate: 0.0010
# Epoch 20/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9536 - sparse_categorical_accuracy: 0.8298 - val_loss: 0.9440 - val_sparse_categorical_accuracy: 0.8672 - learning_rate: 0.0010
# Epoch 21/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9286 - sparse_categorical_accuracy: 0.7874 - val_loss: 0.9232 - val_sparse_categorical_accuracy: 0.9078 - learning_rate: 0.0010
# Epoch 22/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9217 - sparse_categorical_accuracy: 0.8124 - val_loss: 0.9019 - val_sparse_categorical_accuracy: 0.7688 - learning_rate: 0.0010
# Epoch 23/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9012 - sparse_categorical_accuracy: 0.7313 - val_loss: 0.8868 - val_sparse_categorical_accuracy: 0.9453 - learning_rate: 0.0010
# Epoch 24/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8799 - sparse_categorical_accuracy: 0.7998 - val_loss: 0.8693 - val_sparse_categorical_accuracy: 0.9406 - learning_rate: 0.0010
# Epoch 25/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8721 - sparse_categorical_accuracy: 0.9096 - val_loss: 0.8523 - val_sparse_categorical_accuracy: 0.7437 - learning_rate: 0.0010
# Epoch 26/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8408 - sparse_categorical_accuracy: 0.7857 - val_loss: 0.8366 - val_sparse_categorical_accuracy: 0.7453 - learning_rate: 0.0010
# Epoch 27/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8344 - sparse_categorical_accuracy: 0.7574 - val_loss: 0.8233 - val_sparse_categorical_accuracy: 0.9219 - learning_rate: 0.0010
# Epoch 28/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8248 - sparse_categorical_accuracy: 0.8777 - val_loss: 0.8094 - val_sparse_categorical_accuracy: 0.9438 - learning_rate: 0.0010
# Epoch 29/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8090 - sparse_categorical_accuracy: 0.8518 - val_loss: 0.7963 - val_sparse_categorical_accuracy: 0.9406 - learning_rate: 0.0010
# Epoch 30/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8039 - sparse_categorical_accuracy: 0.8504 - val_loss: 0.7834 - val_sparse_categorical_accuracy: 0.8016 - learning_rate: 0.0010
# Epoch 31/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7868 - sparse_categorical_accuracy: 0.8098 - val_loss: 0.7720 - val_sparse_categorical_accuracy: 0.7641 - learning_rate: 0.0010
# Epoch 32/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7745 - sparse_categorical_accuracy: 0.8910 - val_loss: 0.7576 - val_sparse_categorical_accuracy: 0.8188 - learning_rate: 0.0010
# Epoch 33/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7640 - sparse_categorical_accuracy: 0.8747 - val_loss: 0.7452 - val_sparse_categorical_accuracy: 0.9156 - learning_rate: 0.0010
# Epoch 34/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7479 - sparse_categorical_accuracy: 0.8430 - val_loss: 0.7359 - val_sparse_categorical_accuracy: 0.9516 - learning_rate: 0.0010
# Epoch 35/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7363 - sparse_categorical_accuracy: 0.8591 - val_loss: 0.7292 - val_sparse_categorical_accuracy: 0.7578 - learning_rate: 0.0010
# Epoch 36/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7337 - sparse_categorical_accuracy: 0.8762 - val_loss: 0.7139 - val_sparse_categorical_accuracy: 0.9250 - learning_rate: 0.0010
# Epoch 37/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7240 - sparse_categorical_accuracy: 0.8444 - val_loss: 0.7140 - val_sparse_categorical_accuracy: 0.7812 - learning_rate: 0.0010
# Epoch 38/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7175 - sparse_categorical_accuracy: 0.8021 - val_loss: 0.6933 - val_sparse_categorical_accuracy: 0.9359 - learning_rate: 0.0010
# Epoch 39/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7049 - sparse_categorical_accuracy: 0.8678 - val_loss: 0.6835 - val_sparse_categorical_accuracy: 0.8984 - learning_rate: 0.0010
# Epoch 40/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6900 - sparse_categorical_accuracy: 0.9007 - val_loss: 0.6778 - val_sparse_categorical_accuracy: 0.8359 - learning_rate: 0.0010
# Epoch 41/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6757 - sparse_categorical_accuracy: 0.8880 - val_loss: 0.6646 - val_sparse_categorical_accuracy: 0.9438 - learning_rate: 0.0010
# Epoch 42/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6786 - sparse_categorical_accuracy: 0.8772 - val_loss: 0.6605 - val_sparse_categorical_accuracy: 0.9109 - learning_rate: 0.0010
# Epoch 43/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6669 - sparse_categorical_accuracy: 0.8750 - val_loss: 0.6461 - val_sparse_categorical_accuracy: 0.9516 - learning_rate: 0.0010
# Epoch 44/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6522 - sparse_categorical_accuracy: 0.9079 - val_loss: 0.6437 - val_sparse_categorical_accuracy: 0.9312 - learning_rate: 0.0010
# Epoch 45/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6635 - sparse_categorical_accuracy: 0.8813 - val_loss: 0.6356 - val_sparse_categorical_accuracy: 0.9516 - learning_rate: 0.0010
# Epoch 46/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6448 - sparse_categorical_accuracy: 0.8673 - val_loss: 0.6258 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 47/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6260 - sparse_categorical_accuracy: 0.8830 - val_loss: 0.6199 - val_sparse_categorical_accuracy: 0.9438 - learning_rate: 0.0010
# Epoch 48/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6358 - sparse_categorical_accuracy: 0.8559 - val_loss: 0.6118 - val_sparse_categorical_accuracy: 0.9375 - learning_rate: 0.0010
# Epoch 49/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6274 - sparse_categorical_accuracy: 0.8854 - val_loss: 0.6024 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 50/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6141 - sparse_categorical_accuracy: 0.8990 - val_loss: 0.5951 - val_sparse_categorical_accuracy: 0.9453 - learning_rate: 0.0010
# Epoch 51/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6229 - sparse_categorical_accuracy: 0.8883 - val_loss: 0.5906 - val_sparse_categorical_accuracy: 0.9578 - learning_rate: 0.0010
# Epoch 52/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6027 - sparse_categorical_accuracy: 0.9012 - val_loss: 0.5824 - val_sparse_categorical_accuracy: 0.9453 - learning_rate: 0.0010
# Epoch 53/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6074 - sparse_categorical_accuracy: 0.8958 - val_loss: 0.5775 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 54/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5860 - sparse_categorical_accuracy: 0.9339 - val_loss: 0.5718 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 55/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5986 - sparse_categorical_accuracy: 0.8966 - val_loss: 0.5690 - val_sparse_categorical_accuracy: 0.9578 - learning_rate: 0.0010
# Epoch 56/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5911 - sparse_categorical_accuracy: 0.8883 - val_loss: 0.5622 - val_sparse_categorical_accuracy: 0.9328 - learning_rate: 0.0010
# Epoch 57/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5604 - sparse_categorical_accuracy: 0.9032 - val_loss: 0.5522 - val_sparse_categorical_accuracy: 0.9422 - learning_rate: 0.0010
# Epoch 58/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5741 - sparse_categorical_accuracy: 0.8910 - val_loss: 0.5443 - val_sparse_categorical_accuracy: 0.9438 - learning_rate: 0.0010
# Epoch 59/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5650 - sparse_categorical_accuracy: 0.9023 - val_loss: 0.5357 - val_sparse_categorical_accuracy: 0.9578 - learning_rate: 0.0010
# Epoch 60/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5565 - sparse_categorical_accuracy: 0.9140 - val_loss: 0.5321 - val_sparse_categorical_accuracy: 0.9484 - learning_rate: 0.0010
# Epoch 61/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5683 - sparse_categorical_accuracy: 0.8985 - val_loss: 0.5273 - val_sparse_categorical_accuracy: 0.9484 - learning_rate: 0.0010
# Epoch 62/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5447 - sparse_categorical_accuracy: 0.9230 - val_loss: 0.5210 - val_sparse_categorical_accuracy: 0.9625 - learning_rate: 0.0010
# Epoch 63/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5412 - sparse_categorical_accuracy: 0.9129 - val_loss: 0.5186 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 64/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5347 - sparse_categorical_accuracy: 0.9089 - val_loss: 0.5184 - val_sparse_categorical_accuracy: 0.9406 - learning_rate: 0.0010
# Epoch 65/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5368 - sparse_categorical_accuracy: 0.9084 - val_loss: 0.5066 - val_sparse_categorical_accuracy: 0.9500 - learning_rate: 0.0010
# Epoch 66/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5439 - sparse_categorical_accuracy: 0.9068 - val_loss: 0.5011 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 67/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5425 - sparse_categorical_accuracy: 0.9015 - val_loss: 0.5094 - val_sparse_categorical_accuracy: 0.9172 - learning_rate: 0.0010
# Epoch 68/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5177 - sparse_categorical_accuracy: 0.8905 - val_loss: 0.4926 - val_sparse_categorical_accuracy: 0.9438 - learning_rate: 0.0010
# Epoch 69/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5110 - sparse_categorical_accuracy: 0.9106 - val_loss: 0.5004 - val_sparse_categorical_accuracy: 0.9250 - learning_rate: 0.0010
# Epoch 70/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5182 - sparse_categorical_accuracy: 0.9199 - val_loss: 0.4844 - val_sparse_categorical_accuracy: 0.9391 - learning_rate: 0.0010
# Epoch 71/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5301 - sparse_categorical_accuracy: 0.8990 - val_loss: 0.4782 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 72/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5013 - sparse_categorical_accuracy: 0.9255 - val_loss: 0.4800 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 73/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5090 - sparse_categorical_accuracy: 0.9006 - val_loss: 0.4711 - val_sparse_categorical_accuracy: 0.9578 - learning_rate: 0.0010
# Epoch 74/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4984 - sparse_categorical_accuracy: 0.9117 - val_loss: 0.4669 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 75/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4894 - sparse_categorical_accuracy: 0.9313 - val_loss: 0.4662 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 76/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4913 - sparse_categorical_accuracy: 0.9192 - val_loss: 0.4627 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 77/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4867 - sparse_categorical_accuracy: 0.9125 - val_loss: 0.4540 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 78/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4704 - sparse_categorical_accuracy: 0.9236 - val_loss: 0.4476 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 79/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5008 - sparse_categorical_accuracy: 0.9136 - val_loss: 0.4473 - val_sparse_categorical_accuracy: 0.9563 - learning_rate: 0.0010
# Epoch 80/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4735 - sparse_categorical_accuracy: 0.9169 - val_loss: 0.4433 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 81/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4864 - sparse_categorical_accuracy: 0.9155 - val_loss: 0.4376 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 82/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4576 - sparse_categorical_accuracy: 0.9293 - val_loss: 0.4378 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 83/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4672 - sparse_categorical_accuracy: 0.9250 - val_loss: 0.4305 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 84/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4568 - sparse_categorical_accuracy: 0.9220 - val_loss: 0.4355 - val_sparse_categorical_accuracy: 0.9406 - learning_rate: 0.0010
# Epoch 85/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4536 - sparse_categorical_accuracy: 0.9247 - val_loss: 0.4320 - val_sparse_categorical_accuracy: 0.9406 - learning_rate: 0.0010
# Epoch 86/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4743 - sparse_categorical_accuracy: 0.9126 - val_loss: 0.4184 - val_sparse_categorical_accuracy: 0.9531 - learning_rate: 0.0010
# Epoch 87/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4468 - sparse_categorical_accuracy: 0.9278 - val_loss: 0.4170 - val_sparse_categorical_accuracy: 0.9578 - learning_rate: 0.0010
# Epoch 88/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4545 - sparse_categorical_accuracy: 0.9294 - val_loss: 0.4121 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 89/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4497 - sparse_categorical_accuracy: 0.9207 - val_loss: 0.4092 - val_sparse_categorical_accuracy: 0.9578 - learning_rate: 0.0010
# Epoch 90/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4575 - sparse_categorical_accuracy: 0.9124 - val_loss: 0.4062 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 91/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4383 - sparse_categorical_accuracy: 0.9243 - val_loss: 0.4021 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 92/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4363 - sparse_categorical_accuracy: 0.9298 - val_loss: 0.3997 - val_sparse_categorical_accuracy: 0.9516 - learning_rate: 0.0010
# Epoch 93/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4280 - sparse_categorical_accuracy: 0.9288 - val_loss: 0.3961 - val_sparse_categorical_accuracy: 0.9563 - learning_rate: 0.0010
# Epoch 94/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4256 - sparse_categorical_accuracy: 0.9202 - val_loss: 0.3976 - val_sparse_categorical_accuracy: 0.9469 - learning_rate: 0.0010
# Epoch 95/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4484 - sparse_categorical_accuracy: 0.9051 - val_loss: 0.3896 - val_sparse_categorical_accuracy: 0.9563 - learning_rate: 0.0010
# Epoch 96/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4251 - sparse_categorical_accuracy: 0.9228 - val_loss: 0.3900 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 97/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4243 - sparse_categorical_accuracy: 0.9357 - val_loss: 0.3875 - val_sparse_categorical_accuracy: 0.9469 - learning_rate: 0.0010
# Epoch 98/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4442 - sparse_categorical_accuracy: 0.8962 - val_loss: 0.3851 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 99/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4084 - sparse_categorical_accuracy: 0.9325 - val_loss: 0.3803 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 100/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4237 - sparse_categorical_accuracy: 0.9116 - val_loss: 0.3776 - val_sparse_categorical_accuracy: 0.9531 - learning_rate: 0.0010
# Epoch 101/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4314 - sparse_categorical_accuracy: 0.9156 - val_loss: 0.3770 - val_sparse_categorical_accuracy: 0.9453 - learning_rate: 0.0010
# Epoch 102/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3989 - sparse_categorical_accuracy: 0.9276 - val_loss: 0.3685 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 103/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4141 - sparse_categorical_accuracy: 0.9283 - val_loss: 0.3683 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 104/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4096 - sparse_categorical_accuracy: 0.9253 - val_loss: 0.3671 - val_sparse_categorical_accuracy: 0.9500 - learning_rate: 0.0010
# Epoch 105/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3952 - sparse_categorical_accuracy: 0.9332 - val_loss: 0.3693 - val_sparse_categorical_accuracy: 0.9578 - learning_rate: 0.0010
# Epoch 106/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4000 - sparse_categorical_accuracy: 0.9184 - val_loss: 0.3617 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 107/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3970 - sparse_categorical_accuracy: 0.9205 - val_loss: 0.3644 - val_sparse_categorical_accuracy: 0.9484 - learning_rate: 0.0010
# Epoch 108/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3936 - sparse_categorical_accuracy: 0.9201 - val_loss: 0.3578 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 109/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3928 - sparse_categorical_accuracy: 0.9321 - val_loss: 0.3512 - val_sparse_categorical_accuracy: 0.9563 - learning_rate: 0.0010
# Epoch 110/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3979 - sparse_categorical_accuracy: 0.9282 - val_loss: 0.3695 - val_sparse_categorical_accuracy: 0.9328 - learning_rate: 0.0010
# Epoch 111/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3878 - sparse_categorical_accuracy: 0.9307 - val_loss: 0.3508 - val_sparse_categorical_accuracy: 0.9531 - learning_rate: 0.0010
# Epoch 112/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3911 - sparse_categorical_accuracy: 0.9247 - val_loss: 0.3564 - val_sparse_categorical_accuracy: 0.9469 - learning_rate: 0.0010
# Epoch 113/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3793 - sparse_categorical_accuracy: 0.9340 - val_loss: 0.3441 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 114/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4072 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.3410 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 115/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3893 - sparse_categorical_accuracy: 0.9193 - val_loss: 0.3404 - val_sparse_categorical_accuracy: 0.9516 - learning_rate: 0.0010
# Epoch 116/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3729 - sparse_categorical_accuracy: 0.9221 - val_loss: 0.3345 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 117/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3745 - sparse_categorical_accuracy: 0.9367 - val_loss: 0.3381 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 118/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3702 - sparse_categorical_accuracy: 0.9312 - val_loss: 0.3310 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 119/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3761 - sparse_categorical_accuracy: 0.9296 - val_loss: 0.3310 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 120/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3735 - sparse_categorical_accuracy: 0.9182 - val_loss: 0.3270 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 121/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3878 - sparse_categorical_accuracy: 0.9172 - val_loss: 0.3246 - val_sparse_categorical_accuracy: 0.9531 - learning_rate: 0.0010
# Epoch 122/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3615 - sparse_categorical_accuracy: 0.9319 - val_loss: 0.3249 - val_sparse_categorical_accuracy: 0.9578 - learning_rate: 0.0010
# Epoch 123/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3623 - sparse_categorical_accuracy: 0.9280 - val_loss: 0.3240 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 124/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3738 - sparse_categorical_accuracy: 0.9261 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.9469 - learning_rate: 0.0010
# Epoch 125/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3618 - sparse_categorical_accuracy: 0.9264 - val_loss: 0.3204 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 126/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3629 - sparse_categorical_accuracy: 0.9271 - val_loss: 0.3322 - val_sparse_categorical_accuracy: 0.9484 - learning_rate: 0.0010
# Epoch 127/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3705 - sparse_categorical_accuracy: 0.9184 - val_loss: 0.3116 - val_sparse_categorical_accuracy: 0.9625 - learning_rate: 0.0010
# Epoch 128/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3701 - sparse_categorical_accuracy: 0.9145 - val_loss: 0.3162 - val_sparse_categorical_accuracy: 0.9531 - learning_rate: 0.0010
# Epoch 129/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3410 - sparse_categorical_accuracy: 0.9212 - val_loss: 0.3142 - val_sparse_categorical_accuracy: 0.9516 - learning_rate: 0.0010
# Epoch 130/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3410 - sparse_categorical_accuracy: 0.9477 - val_loss: 0.3149 - val_sparse_categorical_accuracy: 0.9516 - learning_rate: 0.0010
# Epoch 131/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3576 - sparse_categorical_accuracy: 0.9231 - val_loss: 0.3097 - val_sparse_categorical_accuracy: 0.9563 - learning_rate: 0.0010
# Epoch 132/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3491 - sparse_categorical_accuracy: 0.9272 - val_loss: 0.3027 - val_sparse_categorical_accuracy: 0.9563 - learning_rate: 0.0010
# Epoch 133/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3423 - sparse_categorical_accuracy: 0.9378 - val_loss: 0.3030 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 134/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3680 - sparse_categorical_accuracy: 0.9149 - val_loss: 0.3003 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 135/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3490 - sparse_categorical_accuracy: 0.9328 - val_loss: 0.3022 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 136/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3618 - sparse_categorical_accuracy: 0.9204 - val_loss: 0.3059 - val_sparse_categorical_accuracy: 0.9531 - learning_rate: 0.0010
# Epoch 137/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3369 - sparse_categorical_accuracy: 0.9235 - val_loss: 0.2949 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 138/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3411 - sparse_categorical_accuracy: 0.9326 - val_loss: 0.2991 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 139/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3469 - sparse_categorical_accuracy: 0.9262 - val_loss: 0.2950 - val_sparse_categorical_accuracy: 0.9563 - learning_rate: 0.0010
# Epoch 140/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3550 - sparse_categorical_accuracy: 0.9247 - val_loss: 0.2923 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 141/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3332 - sparse_categorical_accuracy: 0.9277 - val_loss: 0.2881 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 142/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3452 - sparse_categorical_accuracy: 0.9267 - val_loss: 0.2907 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 143/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3610 - sparse_categorical_accuracy: 0.9211 - val_loss: 0.2883 - val_sparse_categorical_accuracy: 0.9625 - learning_rate: 0.0010
# Epoch 144/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3598 - sparse_categorical_accuracy: 0.9296 - val_loss: 0.2838 - val_sparse_categorical_accuracy: 0.9578 - learning_rate: 0.0010
# Epoch 145/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3378 - sparse_categorical_accuracy: 0.9327 - val_loss: 0.2918 - val_sparse_categorical_accuracy: 0.9516 - learning_rate: 0.0010
# Epoch 146/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3262 - sparse_categorical_accuracy: 0.9400 - val_loss: 0.2799 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 147/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3199 - sparse_categorical_accuracy: 0.9332 - val_loss: 0.2757 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 148/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3323 - sparse_categorical_accuracy: 0.9300 - val_loss: 0.2800 - val_sparse_categorical_accuracy: 0.9641 - learning_rate: 0.0010
# Epoch 149/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3539 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.2785 - val_sparse_categorical_accuracy: 0.9656 - learning_rate: 0.0010
# Epoch 150/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3297 - sparse_categorical_accuracy: 0.9382 - val_loss: 0.2793 - val_sparse_categorical_accuracy: 0.9641 - learning_rate: 0.0010

# %%
# model = keras.saving.load_model("best_model.keras")

# test_loss, test_acc = model.evaluate(x_test, y_test)

# print("Test accuracy", test_acc)
# print("Test loss", test_loss)

# %%
# Load the model
model = keras.saving.load_model("best_model.keras")

# Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2905 - sparse_categorical_accuracy: 0.9500
# Test accuracy: 0.9549999833106995
# Test loss: 0.2808091938495636

# %%
# model info
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 128, 4)         │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 4)         │            16 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 128, 4)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 4)              │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │            20 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 142 (572.00 B)
#  Trainable params: 44 (176.00 B)
#  Non-trainable params: 8 (32.00 B)
#  Optimizer params: 90 (364.00 B)

# %%
import matplotlib.pyplot as plt

# Set font to Times New Roman
plt.rcParams["font.family"] = "Times New Roman"

# Plot training history
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel("accuracy", fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")

# Set x-axis limits
plt.xlim(-20, 160)

# Save the figure
plt.savefig("CNN_Classifier.png")

# Show the plot
plt.show()
plt.close()

# %%
# save model
model.save("cnn_model.keras")

# %%
# save x_test, y_test as npy file, this partition is consistent with the partition in the previous step

# x_test save
np.save('x_test.npy', x_test)

print(x_test.shape)

# y_test save, 1-hot encoding first
tmp_y_test = np.zeros((y_test.shape[0], num_classes))
for i in range(y_test.shape[0]):
    tmp_y_test[i][y_test[i][0]] = 1

np.save('y_test.npy', tmp_y_test)

print(tmp_y_test.shape)
# Out:
# (800, 128, 1)
# (800, 4)

# %%
from PIL import Image

# 打开 PNG 文件
png_image = Image.open("cnn_confusion.png")

# 将图像转换为 RGB 模式（JPG 格式不支持透明通道）
rgb_image = png_image.convert("RGB")

# 保存为 JPG 格式
rgb_image.save("cnn_confusion.jpg", quality=95)
