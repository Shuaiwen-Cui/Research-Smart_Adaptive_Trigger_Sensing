# %% [markdown]
# # CNN FOR EVENT CLASSIFICATION

# %% [markdown]
# ## DATA GENERATION

# %%
# DEPENDENCIES

import numpy as np
import sys
import os
import matplotlib.pyplot as plt
import random
import time
import datetime
import pandas as pd

import prenn # for deep learning

# %%
# RAW DATA
AVPath = '../DATA/SYN_RES/RESPONSE_AV.npy'
EQPath = '../DATA/SYN_RES/RESPONSE_EQ.npy'
IPPath = '../DATA/SYN_RES/RESPONSE_IP.npy'
SWPath = '../DATA/SYN_RES/RESPONSE_SW.npy'

# Load Data + add noise to the data
RESPONSE_AV = np.load(AVPath)
RESPONSE_EQ = np.load(EQPath)
RESPONSE_IP = np.load(IPPath)
RESPONSE_SW = np.load(SWPath)

## only use part of the data
raw_len = RESPONSE_AV.shape[0]
ratio = 1.0 # ALL DATA USED FOR TRAINING
use_len = int(raw_len * ratio)

RESPONSE_AV = RESPONSE_AV[:use_len]
RESPONSE_EQ = RESPONSE_EQ[:use_len]
RESPONSE_IP = RESPONSE_IP[:use_len]
RESPONSE_SW = RESPONSE_SW[:use_len]

## Check Data Info
print(type(RESPONSE_AV))
print('RESPONSE_AV Shape:', RESPONSE_AV.shape)
print(type(RESPONSE_EQ))
print('RESPONSE_EQ Shape:', RESPONSE_EQ.shape)
print(type(RESPONSE_IP))
print('RESPONSE_IP Shape:', RESPONSE_IP.shape)
print(type(RESPONSE_SW))
print('RESPONSE_SW Shape:', RESPONSE_SW.shape)
# Out:
# <class 'numpy.ndarray'>
# RESPONSE_AV Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_EQ Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_IP Shape: (1000, 6000)
# <class 'numpy.ndarray'>
# RESPONSE_SW Shape: (1000, 6000)

# %%
## Check Random Data
selected_idx = np.random.randint(RESPONSE_AV.shape[0])

## Plot Random Data - use subplot
plt.figure(figsize=(30, 10))
plt.subplot(2, 2, 1)
plt.plot(RESPONSE_AV[selected_idx, :])
plt.title('AV')
plt.subplot(2, 2, 2)
plt.plot(RESPONSE_EQ[selected_idx, :])
plt.title('EQ')
plt.subplot(2, 2, 3)
plt.plot(RESPONSE_IP[selected_idx, :])
plt.title('IP')
plt.subplot(2, 2, 4)
plt.plot(RESPONSE_SW[selected_idx, :])
plt.title('SW')
plt.show()

# %%
num_type = 4

reshape_shape_0 = RESPONSE_AV.shape[0]
reshape_shape_1 = RESPONSE_AV.shape[1]

LenTS = reshape_shape_1

# %%
# Integrate All Data into a 2D Array

## Reshape Data
RESPONSE_AV_RESHAPED = RESPONSE_AV.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_EQ_RESHAPED = RESPONSE_EQ.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_IP_RESHAPED = RESPONSE_IP.reshape(reshape_shape_0, reshape_shape_1)
RESPONSE_SW_RESHAPED = RESPONSE_SW.reshape(reshape_shape_0, reshape_shape_1)

## Stack Data
RESPONSE = np.vstack((RESPONSE_AV_RESHAPED, RESPONSE_EQ_RESHAPED, RESPONSE_IP_RESHAPED, RESPONSE_SW_RESHAPED))

## Total Number of Samples
NumSample = RESPONSE.shape[0]
print('Total Number of Samples:', NumSample)
# Out:
# Total Number of Samples: 4000

# %%
# Real Ground Truth

## Binary Form, Interest or Not
Real_GT_B = np.zeros((RESPONSE.shape[0], 1))

## Real_GT_B, only the first quarter of the data is considered as not interesting
for i in range(RESPONSE_AV.shape[0], RESPONSE.shape[0]):
    Real_GT_B[i] = 1

## plot the binary form
plt.figure()
plt.plot(Real_GT_B)
plt.show()

## Multi-Class Form, Event Type
Real_GT_M = np.zeros((RESPONSE.shape[0], 4))

## Real_GT_M, 4 types of events
for i in range(num_type):
    Real_GT_M[i*reshape_shape_0:(i+1)*reshape_shape_0, i] = 1

## plot the multi-class form, 4 subplots, each subplot for one type of event
plt.figure(figsize=(30, 10))
plt.subplot(4, 1, 1)
plt.plot(Real_GT_M[:, 0])
plt.title('AV')
plt.subplot(4, 1, 2)
plt.plot(Real_GT_M[:, 1])
plt.title('EQ')
plt.subplot(4, 1, 3)
plt.plot(Real_GT_M[:, 2])
plt.title('IP')
plt.subplot(4, 1, 4)
plt.plot(Real_GT_M[:, 3])
plt.title('SW')
plt.show()

# %%
# process parameters

# nn input length
nn_in_len = 128

# time step
dt = 0.01

# nperseg
nperseg = 128

# output length

# %%
NN_IN_DATA = np.zeros((NumSample, nn_in_len))

for i in range(NumSample):
    NN_IN_DATA[i, :] = prenn.prenn(RESPONSE[i, :].reshape(1, -1), dt, nperseg, nn_in_len)

# %%
# check whether nan exists
nan_idx = np.argwhere(np.isnan(NN_IN_DATA))
print(nan_idx)
# Out:
# []

# %%
# plot to check
# selected_idx = np.random.randint(NumSample)
selected_idx = 599
plt.figure()
plt.plot(NN_IN_DATA[selected_idx, :])
plt.show()

# %%
# save data as npy file
np.save('NN_IN_DATA.npy', NN_IN_DATA)

# %%
# LABELS
NN_IN_LABEL = np.zeros((NumSample, 1))
NN_IN_LABEL_1HOT = np.zeros((NumSample, 4))

# %%
# NN_IN_LABEL & NN_IN_LABEL_1HOT
for i in range(NumSample):
    if i < reshape_shape_0:
        NN_IN_LABEL[i] = 0
        NN_IN_LABEL_1HOT[i, 0] = 1
    elif i < reshape_shape_0 * 2:
        NN_IN_LABEL[i] = 1
        NN_IN_LABEL_1HOT[i, 1] = 1
    elif i < reshape_shape_0 * 3:
        NN_IN_LABEL[i] = 2
        NN_IN_LABEL_1HOT[i, 2] = 1
    else:
        NN_IN_LABEL[i] = 3
        NN_IN_LABEL_1HOT[i, 3] = 1

# %%
## plot NN_IN_LABEL
plt.figure()
plt.plot(NN_IN_LABEL)
plt.show()

# %%
## plot NN_IN_LABEL_1HOT
plt.figure(figsize=(30, 10))
plt.subplot(4, 1, 1)
plt.plot(NN_IN_LABEL_1HOT[:, 0])
plt.title('AV')
plt.subplot(4, 1, 2)
plt.plot(NN_IN_LABEL_1HOT[:, 1])
plt.title('EQ')
plt.subplot(4, 1, 3)
plt.plot(NN_IN_LABEL_1HOT[:, 2])
plt.title('IP')
plt.subplot(4, 1, 4)
plt.plot(NN_IN_LABEL_1HOT[:, 3])
plt.title('SW')
plt.show()

# %%
# save data as npy file
np.save('NN_IN_LABEL.npy', NN_IN_LABEL)
np.save('NN_IN_LABEL_1HOT.npy', NN_IN_LABEL_1HOT)

# %% [markdown]
# ## CNN MODEL FOR CLASSIFICATION

# %%
# dependencies
import numpy as np
import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
import tf2onnx
import onnx
# Out:
# WARNING:tensorflow:From C:\Users\cswof\AppData\Roaming\Python\Python312\site-packages\tf2onnx\tf_loader.py:68: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\cswof\AppData\Roaming\Python\Python312\site-packages\tf2onnx\tf_loader.py:72: The name tf.train.import_meta_graph is deprecated. Please use tf.compat.v1.train.import_meta_graph instead.

# %%
# data preparation

data = np.load('NN_IN_DATA.npy')
# expand dimensions to 3D
data = np.expand_dims(data, axis=2)

print(data.shape)

label_1h = np.load('NN_IN_LABEL_1HOT.npy').astype(int)
print(label_1h.shape)

label = np.argmax(label_1h, axis=1).astype(int)
label = label.reshape((-1,1))

print(label.shape)
# Out:
# (4000, 128, 1)
# (4000, 4)
# (4000, 1)

# %%
# split data as x_train, x_test, y_train, y_test
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=42)

# check info
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3200, 128, 1)
# (800, 128, 1)
# (3200, 1)
# (800, 1)

# %%
num_classes = np.unique(label).shape[0]
print(num_classes)
# Out:
# 4

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=4, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    # conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    # conv2 = keras.layers.BatchNormalization()(conv2)
    # conv2 = keras.layers.ReLU()(conv2)

    # conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    # conv3 = keras.layers.BatchNormalization()(conv3)
    # conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv1)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
# keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 150
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.3864 - sparse_categorical_accuracy: 0.2589 - val_loss: 1.3649 - val_sparse_categorical_accuracy: 0.4797 - learning_rate: 0.0010
# Epoch 2/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3645 - sparse_categorical_accuracy: 0.4722 - val_loss: 1.3482 - val_sparse_categorical_accuracy: 0.3609 - learning_rate: 0.0010
# Epoch 3/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3329 - sparse_categorical_accuracy: 0.5147 - val_loss: 1.3279 - val_sparse_categorical_accuracy: 0.3688 - learning_rate: 0.0010
# Epoch 4/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2998 - sparse_categorical_accuracy: 0.4823 - val_loss: 1.3034 - val_sparse_categorical_accuracy: 0.5828 - learning_rate: 0.0010
# Epoch 5/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2708 - sparse_categorical_accuracy: 0.6501 - val_loss: 1.2703 - val_sparse_categorical_accuracy: 0.7375 - learning_rate: 0.0010
# Epoch 6/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2557 - sparse_categorical_accuracy: 0.6670 - val_loss: 1.2433 - val_sparse_categorical_accuracy: 0.6656 - learning_rate: 0.0010
# Epoch 7/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2374 - sparse_categorical_accuracy: 0.5920 - val_loss: 1.2212 - val_sparse_categorical_accuracy: 0.7109 - learning_rate: 0.0010
# Epoch 8/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2117 - sparse_categorical_accuracy: 0.6741 - val_loss: 1.1967 - val_sparse_categorical_accuracy: 0.7219 - learning_rate: 0.0010
# Epoch 9/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1902 - sparse_categorical_accuracy: 0.7016 - val_loss: 1.1771 - val_sparse_categorical_accuracy: 0.7047 - learning_rate: 0.0010
# Epoch 10/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1728 - sparse_categorical_accuracy: 0.6927 - val_loss: 1.1505 - val_sparse_categorical_accuracy: 0.7344 - learning_rate: 0.0010
# Epoch 11/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1399 - sparse_categorical_accuracy: 0.7093 - val_loss: 1.1306 - val_sparse_categorical_accuracy: 0.7172 - learning_rate: 0.0010
# Epoch 12/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1303 - sparse_categorical_accuracy: 0.7141 - val_loss: 1.1057 - val_sparse_categorical_accuracy: 0.7375 - learning_rate: 0.0010
# Epoch 13/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1116 - sparse_categorical_accuracy: 0.6961 - val_loss: 1.0836 - val_sparse_categorical_accuracy: 0.7297 - learning_rate: 0.0010
# Epoch 14/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0807 - sparse_categorical_accuracy: 0.7008 - val_loss: 1.0617 - val_sparse_categorical_accuracy: 0.7219 - learning_rate: 0.0010
# Epoch 15/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0672 - sparse_categorical_accuracy: 0.6976 - val_loss: 1.0374 - val_sparse_categorical_accuracy: 0.7000 - learning_rate: 0.0010
# Epoch 16/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0336 - sparse_categorical_accuracy: 0.6918 - val_loss: 1.0163 - val_sparse_categorical_accuracy: 0.6984 - learning_rate: 0.0010
# Epoch 17/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0126 - sparse_categorical_accuracy: 0.7075 - val_loss: 0.9967 - val_sparse_categorical_accuracy: 0.7359 - learning_rate: 0.0010
# Epoch 18/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9862 - sparse_categorical_accuracy: 0.7241 - val_loss: 0.9758 - val_sparse_categorical_accuracy: 0.7453 - learning_rate: 0.0010
# Epoch 19/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9742 - sparse_categorical_accuracy: 0.7134 - val_loss: 0.9516 - val_sparse_categorical_accuracy: 0.7516 - learning_rate: 0.0010
# Epoch 20/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9453 - sparse_categorical_accuracy: 0.7237 - val_loss: 0.9313 - val_sparse_categorical_accuracy: 0.7453 - learning_rate: 0.0010
# Epoch 21/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9317 - sparse_categorical_accuracy: 0.7431 - val_loss: 0.9090 - val_sparse_categorical_accuracy: 0.7469 - learning_rate: 0.0010
# Epoch 22/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9072 - sparse_categorical_accuracy: 0.7429 - val_loss: 0.8864 - val_sparse_categorical_accuracy: 0.7531 - learning_rate: 0.0010
# Epoch 23/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8875 - sparse_categorical_accuracy: 0.7695 - val_loss: 0.8699 - val_sparse_categorical_accuracy: 0.8047 - learning_rate: 0.0010
# Epoch 24/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8788 - sparse_categorical_accuracy: 0.7604 - val_loss: 0.8513 - val_sparse_categorical_accuracy: 0.7906 - learning_rate: 0.0010
# Epoch 25/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8515 - sparse_categorical_accuracy: 0.8107 - val_loss: 0.8367 - val_sparse_categorical_accuracy: 0.7547 - learning_rate: 0.0010
# Epoch 26/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8413 - sparse_categorical_accuracy: 0.7913 - val_loss: 0.8265 - val_sparse_categorical_accuracy: 0.7437 - learning_rate: 0.0010
# Epoch 27/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8225 - sparse_categorical_accuracy: 0.8212 - val_loss: 0.8105 - val_sparse_categorical_accuracy: 0.7500 - learning_rate: 0.0010
# Epoch 28/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8099 - sparse_categorical_accuracy: 0.8201 - val_loss: 0.7970 - val_sparse_categorical_accuracy: 0.8781 - learning_rate: 0.0010
# Epoch 29/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7938 - sparse_categorical_accuracy: 0.8261 - val_loss: 0.7846 - val_sparse_categorical_accuracy: 0.8266 - learning_rate: 0.0010
# Epoch 30/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7837 - sparse_categorical_accuracy: 0.8535 - val_loss: 0.7733 - val_sparse_categorical_accuracy: 0.8875 - learning_rate: 0.0010
# Epoch 31/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7765 - sparse_categorical_accuracy: 0.8691 - val_loss: 0.7634 - val_sparse_categorical_accuracy: 0.8516 - learning_rate: 0.0010
# Epoch 32/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7685 - sparse_categorical_accuracy: 0.8649 - val_loss: 0.7531 - val_sparse_categorical_accuracy: 0.9344 - learning_rate: 0.0010
# Epoch 33/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7615 - sparse_categorical_accuracy: 0.8718 - val_loss: 0.7421 - val_sparse_categorical_accuracy: 0.8781 - learning_rate: 0.0010
# Epoch 34/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7506 - sparse_categorical_accuracy: 0.8632 - val_loss: 0.7357 - val_sparse_categorical_accuracy: 0.8391 - learning_rate: 0.0010
# Epoch 35/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7342 - sparse_categorical_accuracy: 0.8791 - val_loss: 0.7250 - val_sparse_categorical_accuracy: 0.8687 - learning_rate: 0.0010
# Epoch 36/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7363 - sparse_categorical_accuracy: 0.8904 - val_loss: 0.7159 - val_sparse_categorical_accuracy: 0.8281 - learning_rate: 0.0010
# Epoch 37/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7097 - sparse_categorical_accuracy: 0.8956 - val_loss: 0.7044 - val_sparse_categorical_accuracy: 0.8734 - learning_rate: 0.0010
# Epoch 38/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7053 - sparse_categorical_accuracy: 0.9010 - val_loss: 0.6934 - val_sparse_categorical_accuracy: 0.8734 - learning_rate: 0.0010
# Epoch 39/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7197 - sparse_categorical_accuracy: 0.8996 - val_loss: 0.6883 - val_sparse_categorical_accuracy: 0.8266 - learning_rate: 0.0010
# Epoch 40/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6908 - sparse_categorical_accuracy: 0.9091 - val_loss: 0.6795 - val_sparse_categorical_accuracy: 0.8531 - learning_rate: 0.0010
# Epoch 41/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6814 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.6683 - val_sparse_categorical_accuracy: 0.8781 - learning_rate: 0.0010
# Epoch 42/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6711 - sparse_categorical_accuracy: 0.9074 - val_loss: 0.6643 - val_sparse_categorical_accuracy: 0.8641 - learning_rate: 0.0010
# Epoch 43/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6729 - sparse_categorical_accuracy: 0.9136 - val_loss: 0.6533 - val_sparse_categorical_accuracy: 0.9062 - learning_rate: 0.0010
# Epoch 44/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6664 - sparse_categorical_accuracy: 0.9194 - val_loss: 0.6448 - val_sparse_categorical_accuracy: 0.9062 - learning_rate: 0.0010
# Epoch 45/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6415 - sparse_categorical_accuracy: 0.9252 - val_loss: 0.6364 - val_sparse_categorical_accuracy: 0.9000 - learning_rate: 0.0010
# Epoch 46/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6370 - sparse_categorical_accuracy: 0.9211 - val_loss: 0.6352 - val_sparse_categorical_accuracy: 0.8609 - learning_rate: 0.0010
# Epoch 47/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6467 - sparse_categorical_accuracy: 0.9262 - val_loss: 0.6219 - val_sparse_categorical_accuracy: 0.9109 - learning_rate: 0.0010
# Epoch 48/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6424 - sparse_categorical_accuracy: 0.9133 - val_loss: 0.6196 - val_sparse_categorical_accuracy: 0.9031 - learning_rate: 0.0010
# Epoch 49/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6293 - sparse_categorical_accuracy: 0.9040 - val_loss: 0.6213 - val_sparse_categorical_accuracy: 0.8375 - learning_rate: 0.0010
# Epoch 50/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6161 - sparse_categorical_accuracy: 0.9253 - val_loss: 0.6034 - val_sparse_categorical_accuracy: 0.9422 - learning_rate: 0.0010
# Epoch 51/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6086 - sparse_categorical_accuracy: 0.9244 - val_loss: 0.5955 - val_sparse_categorical_accuracy: 0.9375 - learning_rate: 0.0010
# Epoch 52/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5989 - sparse_categorical_accuracy: 0.9336 - val_loss: 0.5896 - val_sparse_categorical_accuracy: 0.9406 - learning_rate: 0.0010
# Epoch 53/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5913 - sparse_categorical_accuracy: 0.9335 - val_loss: 0.5819 - val_sparse_categorical_accuracy: 0.9391 - learning_rate: 0.0010
# Epoch 54/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5970 - sparse_categorical_accuracy: 0.9316 - val_loss: 0.5729 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 55/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5873 - sparse_categorical_accuracy: 0.9223 - val_loss: 0.5683 - val_sparse_categorical_accuracy: 0.9563 - learning_rate: 0.0010
# Epoch 56/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5748 - sparse_categorical_accuracy: 0.9453 - val_loss: 0.5617 - val_sparse_categorical_accuracy: 0.9641 - learning_rate: 0.0010
# Epoch 57/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5765 - sparse_categorical_accuracy: 0.9298 - val_loss: 0.5558 - val_sparse_categorical_accuracy: 0.9531 - learning_rate: 0.0010
# Epoch 58/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5722 - sparse_categorical_accuracy: 0.9469 - val_loss: 0.5586 - val_sparse_categorical_accuracy: 0.9641 - learning_rate: 0.0010
# Epoch 59/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5718 - sparse_categorical_accuracy: 0.9378 - val_loss: 0.5456 - val_sparse_categorical_accuracy: 0.9656 - learning_rate: 0.0010
# Epoch 60/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5667 - sparse_categorical_accuracy: 0.9446 - val_loss: 0.5377 - val_sparse_categorical_accuracy: 0.9531 - learning_rate: 0.0010
# Epoch 61/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5616 - sparse_categorical_accuracy: 0.9378 - val_loss: 0.5372 - val_sparse_categorical_accuracy: 0.9500 - learning_rate: 0.0010
# Epoch 62/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5446 - sparse_categorical_accuracy: 0.9419 - val_loss: 0.5280 - val_sparse_categorical_accuracy: 0.9500 - learning_rate: 0.0010
# Epoch 63/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5474 - sparse_categorical_accuracy: 0.9435 - val_loss: 0.5214 - val_sparse_categorical_accuracy: 0.9625 - learning_rate: 0.0010
# Epoch 64/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5462 - sparse_categorical_accuracy: 0.9413 - val_loss: 0.5174 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 65/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5323 - sparse_categorical_accuracy: 0.9515 - val_loss: 0.5135 - val_sparse_categorical_accuracy: 0.9625 - learning_rate: 0.0010
# Epoch 66/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5171 - sparse_categorical_accuracy: 0.9496 - val_loss: 0.5052 - val_sparse_categorical_accuracy: 0.9563 - learning_rate: 0.0010
# Epoch 67/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5136 - sparse_categorical_accuracy: 0.9572 - val_loss: 0.5023 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 68/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5273 - sparse_categorical_accuracy: 0.9463 - val_loss: 0.4986 - val_sparse_categorical_accuracy: 0.9531 - learning_rate: 0.0010
# Epoch 69/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5147 - sparse_categorical_accuracy: 0.9459 - val_loss: 0.4948 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 70/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5078 - sparse_categorical_accuracy: 0.9480 - val_loss: 0.4855 - val_sparse_categorical_accuracy: 0.9516 - learning_rate: 0.0010
# Epoch 71/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5145 - sparse_categorical_accuracy: 0.9523 - val_loss: 0.4825 - val_sparse_categorical_accuracy: 0.9547 - learning_rate: 0.0010
# Epoch 72/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4967 - sparse_categorical_accuracy: 0.9557 - val_loss: 0.4762 - val_sparse_categorical_accuracy: 0.9625 - learning_rate: 0.0010
# Epoch 73/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4929 - sparse_categorical_accuracy: 0.9553 - val_loss: 0.4724 - val_sparse_categorical_accuracy: 0.9563 - learning_rate: 0.0010
# Epoch 74/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4967 - sparse_categorical_accuracy: 0.9459 - val_loss: 0.4650 - val_sparse_categorical_accuracy: 0.9688 - learning_rate: 0.0010
# Epoch 75/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5019 - sparse_categorical_accuracy: 0.9448 - val_loss: 0.4628 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 76/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4829 - sparse_categorical_accuracy: 0.9533 - val_loss: 0.4564 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 77/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4872 - sparse_categorical_accuracy: 0.9454 - val_loss: 0.4524 - val_sparse_categorical_accuracy: 0.9625 - learning_rate: 0.0010
# Epoch 78/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4784 - sparse_categorical_accuracy: 0.9536 - val_loss: 0.4510 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 79/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4781 - sparse_categorical_accuracy: 0.9515 - val_loss: 0.4436 - val_sparse_categorical_accuracy: 0.9703 - learning_rate: 0.0010
# Epoch 80/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4734 - sparse_categorical_accuracy: 0.9497 - val_loss: 0.4429 - val_sparse_categorical_accuracy: 0.9672 - learning_rate: 0.0010
# Epoch 81/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4591 - sparse_categorical_accuracy: 0.9591 - val_loss: 0.4426 - val_sparse_categorical_accuracy: 0.9656 - learning_rate: 0.0010
# Epoch 82/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4582 - sparse_categorical_accuracy: 0.9565 - val_loss: 0.4371 - val_sparse_categorical_accuracy: 0.9672 - learning_rate: 0.0010
# Epoch 83/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4670 - sparse_categorical_accuracy: 0.9521 - val_loss: 0.4295 - val_sparse_categorical_accuracy: 0.9703 - learning_rate: 0.0010
# Epoch 84/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4553 - sparse_categorical_accuracy: 0.9559 - val_loss: 0.4244 - val_sparse_categorical_accuracy: 0.9625 - learning_rate: 0.0010
# Epoch 85/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4363 - sparse_categorical_accuracy: 0.9638 - val_loss: 0.4220 - val_sparse_categorical_accuracy: 0.9594 - learning_rate: 0.0010
# Epoch 86/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4233 - sparse_categorical_accuracy: 0.9678 - val_loss: 0.4131 - val_sparse_categorical_accuracy: 0.9688 - learning_rate: 0.0010
# Epoch 87/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4495 - sparse_categorical_accuracy: 0.9510 - val_loss: 0.4160 - val_sparse_categorical_accuracy: 0.9641 - learning_rate: 0.0010
# Epoch 88/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4225 - sparse_categorical_accuracy: 0.9561 - val_loss: 0.4068 - val_sparse_categorical_accuracy: 0.9703 - learning_rate: 0.0010
# Epoch 89/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4310 - sparse_categorical_accuracy: 0.9566 - val_loss: 0.4149 - val_sparse_categorical_accuracy: 0.9641 - learning_rate: 0.0010
# Epoch 90/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4239 - sparse_categorical_accuracy: 0.9567 - val_loss: 0.4016 - val_sparse_categorical_accuracy: 0.9656 - learning_rate: 0.0010
# Epoch 91/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4385 - sparse_categorical_accuracy: 0.9501 - val_loss: 0.3965 - val_sparse_categorical_accuracy: 0.9641 - learning_rate: 0.0010
# Epoch 92/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4155 - sparse_categorical_accuracy: 0.9631 - val_loss: 0.3935 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 93/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4125 - sparse_categorical_accuracy: 0.9549 - val_loss: 0.3882 - val_sparse_categorical_accuracy: 0.9688 - learning_rate: 0.0010
# Epoch 94/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4183 - sparse_categorical_accuracy: 0.9493 - val_loss: 0.3883 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 95/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4066 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.3869 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 96/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4137 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.3765 - val_sparse_categorical_accuracy: 0.9688 - learning_rate: 0.0010
# Epoch 97/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4012 - sparse_categorical_accuracy: 0.9629 - val_loss: 0.3731 - val_sparse_categorical_accuracy: 0.9703 - learning_rate: 0.0010
# Epoch 98/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3979 - sparse_categorical_accuracy: 0.9561 - val_loss: 0.3704 - val_sparse_categorical_accuracy: 0.9703 - learning_rate: 0.0010
# Epoch 99/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3918 - sparse_categorical_accuracy: 0.9610 - val_loss: 0.3710 - val_sparse_categorical_accuracy: 0.9688 - learning_rate: 0.0010
# Epoch 100/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3906 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.3630 - val_sparse_categorical_accuracy: 0.9703 - learning_rate: 0.0010
# Epoch 101/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3830 - sparse_categorical_accuracy: 0.9598 - val_loss: 0.3632 - val_sparse_categorical_accuracy: 0.9672 - learning_rate: 0.0010
# Epoch 102/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3925 - sparse_categorical_accuracy: 0.9574 - val_loss: 0.3667 - val_sparse_categorical_accuracy: 0.9609 - learning_rate: 0.0010
# Epoch 103/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3775 - sparse_categorical_accuracy: 0.9619 - val_loss: 0.3575 - val_sparse_categorical_accuracy: 0.9672 - learning_rate: 0.0010
# Epoch 104/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3679 - sparse_categorical_accuracy: 0.9688 - val_loss: 0.3529 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 105/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3673 - sparse_categorical_accuracy: 0.9676 - val_loss: 0.3506 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 106/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3592 - sparse_categorical_accuracy: 0.9683 - val_loss: 0.3459 - val_sparse_categorical_accuracy: 0.9688 - learning_rate: 0.0010
# Epoch 107/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3531 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.3389 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 108/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3595 - sparse_categorical_accuracy: 0.9666 - val_loss: 0.3374 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 109/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3528 - sparse_categorical_accuracy: 0.9621 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 110/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3648 - sparse_categorical_accuracy: 0.9644 - val_loss: 0.3488 - val_sparse_categorical_accuracy: 0.9625 - learning_rate: 0.0010
# Epoch 111/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3607 - sparse_categorical_accuracy: 0.9632 - val_loss: 0.3295 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 112/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3562 - sparse_categorical_accuracy: 0.9629 - val_loss: 0.3268 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 113/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3449 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.3247 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 114/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3422 - sparse_categorical_accuracy: 0.9696 - val_loss: 0.3198 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 115/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3548 - sparse_categorical_accuracy: 0.9498 - val_loss: 0.3219 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 116/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3470 - sparse_categorical_accuracy: 0.9605 - val_loss: 0.3148 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 117/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3418 - sparse_categorical_accuracy: 0.9630 - val_loss: 0.3116 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 118/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3269 - sparse_categorical_accuracy: 0.9713 - val_loss: 0.3108 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 119/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3380 - sparse_categorical_accuracy: 0.9575 - val_loss: 0.3173 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 120/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3312 - sparse_categorical_accuracy: 0.9621 - val_loss: 0.3038 - val_sparse_categorical_accuracy: 0.9703 - learning_rate: 0.0010
# Epoch 121/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3247 - sparse_categorical_accuracy: 0.9706 - val_loss: 0.3005 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 122/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3287 - sparse_categorical_accuracy: 0.9678 - val_loss: 0.2988 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 123/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3176 - sparse_categorical_accuracy: 0.9685 - val_loss: 0.2976 - val_sparse_categorical_accuracy: 0.9766 - learning_rate: 0.0010
# Epoch 124/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3174 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.2944 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 125/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3083 - sparse_categorical_accuracy: 0.9699 - val_loss: 0.2914 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 126/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3235 - sparse_categorical_accuracy: 0.9627 - val_loss: 0.2951 - val_sparse_categorical_accuracy: 0.9688 - learning_rate: 0.0010
# Epoch 127/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3148 - sparse_categorical_accuracy: 0.9643 - val_loss: 0.2871 - val_sparse_categorical_accuracy: 0.9703 - learning_rate: 0.0010
# Epoch 128/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3130 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.2832 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 129/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2955 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.2823 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 130/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2865 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.2771 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 131/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2879 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.2922 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 132/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2938 - sparse_categorical_accuracy: 0.9711 - val_loss: 0.2767 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 133/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3148 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.2712 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 134/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2956 - sparse_categorical_accuracy: 0.9685 - val_loss: 0.2691 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 135/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3055 - sparse_categorical_accuracy: 0.9611 - val_loss: 0.2698 - val_sparse_categorical_accuracy: 0.9688 - learning_rate: 0.0010
# Epoch 136/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2834 - sparse_categorical_accuracy: 0.9690 - val_loss: 0.2687 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 137/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2948 - sparse_categorical_accuracy: 0.9684 - val_loss: 0.2647 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 138/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2781 - sparse_categorical_accuracy: 0.9693 - val_loss: 0.2666 - val_sparse_categorical_accuracy: 0.9703 - learning_rate: 0.0010
# Epoch 139/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3007 - sparse_categorical_accuracy: 0.9584 - val_loss: 0.2587 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 140/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2926 - sparse_categorical_accuracy: 0.9650 - val_loss: 0.2578 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 141/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2906 - sparse_categorical_accuracy: 0.9689 - val_loss: 0.2551 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 142/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2817 - sparse_categorical_accuracy: 0.9643 - val_loss: 0.2548 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 143/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2797 - sparse_categorical_accuracy: 0.9685 - val_loss: 0.2496 - val_sparse_categorical_accuracy: 0.9734 - learning_rate: 0.0010
# Epoch 144/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2627 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.2486 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 145/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2856 - sparse_categorical_accuracy: 0.9686 - val_loss: 0.2484 - val_sparse_categorical_accuracy: 0.9766 - learning_rate: 0.0010
# Epoch 146/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2575 - sparse_categorical_accuracy: 0.9754 - val_loss: 0.2429 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 147/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2603 - sparse_categorical_accuracy: 0.9744 - val_loss: 0.2524 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010
# Epoch 148/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2672 - sparse_categorical_accuracy: 0.9716 - val_loss: 0.2417 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 149/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2576 - sparse_categorical_accuracy: 0.9705 - val_loss: 0.2419 - val_sparse_categorical_accuracy: 0.9719 - learning_rate: 0.0010
# Epoch 150/150
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2720 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.2388 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 0.0010

# %%
# model = keras.saving.load_model("best_model.keras")

# test_loss, test_acc = model.evaluate(x_test, y_test)

# print("Test accuracy", test_acc)
# print("Test loss", test_loss)

# %%
# Load the model
model = keras.saving.load_model("best_model.keras")

# Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2273 - sparse_categorical_accuracy: 0.9814
# Test accuracy: 0.981249988079071
# Test loss: 0.22414875030517578

# %%
# model info
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 128, 4)         │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 4)         │            16 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 128, 4)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 4)              │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │            20 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 142 (572.00 B)
#  Trainable params: 44 (176.00 B)
#  Non-trainable params: 8 (32.00 B)
#  Optimizer params: 90 (364.00 B)

# %%
import matplotlib.pyplot as plt

# Set font to Times New Roman
plt.rcParams["font.family"] = "Times New Roman"

# Plot training history
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel("accuracy", fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")

# Set x-axis limits
plt.xlim(-20, 160)

# Save the figure
plt.savefig("CNN_Classifier.png")

# Show the plot
plt.show()
plt.close()

# %%
# save model
model.save("cnn_model.keras")

# %%
import matplotlib.pyplot as plt

# Set font to Times New Roman
plt.rcParams["font.family"] = "Times New Roman"

# Plot training history
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("CNN Classifier Training Curve")
plt.ylabel("Accuracy", fontsize="large")
plt.xlabel("Epoch", fontsize="large")
plt.legend(["Train", "Val"], loc="best")

# Set x-axis limits
plt.xlim(-20, 160)

# Save the figure
plt.savefig("CNN_Classifier.png")

# Show the plot
plt.show()
plt.close()

# %%
# save x_test, y_test as npy file, this partition is consistent with the partition in the previous step

# x_test save
np.save('x_test.npy', x_test)

print(x_test.shape)

# y_test save, 1-hot encoding first
tmp_y_test = np.zeros((y_test.shape[0], num_classes))
for i in range(y_test.shape[0]):
    tmp_y_test[i][y_test[i][0]] = 1

np.save('y_test.npy', tmp_y_test)

print(tmp_y_test.shape)
# Out:
# (800, 128, 1)
# (800, 4)
